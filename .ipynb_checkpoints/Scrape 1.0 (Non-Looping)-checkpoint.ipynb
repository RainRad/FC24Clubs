# %%
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as soup
import datetime
import json
import requests
import sys
import time

# %%
leaderboard_df = pd.read_csv('T100Leaderboard.csv')
leaderboard_df = leaderboard_df[["clubId", "platform"]]
leaderboard_df.head(3)
leaderboard_df = leaderboard_df[0:10]
leaderboard_df
# Out:
#    clubId     platform
# 0   13541  common-gen4
# 1   17186  common-gen4
# 2   14226  common-gen4
# 3   33961  common-gen4
# 4   16046  common-gen4
# 5  347426  common-gen4
# 6  545151  common-gen4
# 7  526006  common-gen4
# 8  295561  common-gen4
# 9  639456  common-gen4

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
match_overview_dictionary_list = []

# %%
vproattr_key_names = [
    "vproattr_1", "vproattr_2", "vproattr_3", "vproattr_4", "vproattr_5",
    "vproattr_6", "vproattr_7", "vproattr_8", "vproattr_9", "vproattr_10",
    "vproattr_11", "vproattr_12", "vproattr_13", "vproattr_14", "vproattr_15",
    "vproattr_16", "vproattr_17", "vproattr_18", "vproattr_19", "vproattr_20",
    "vproattr_21", "vproattr_22", "vproattr_23", "vproattr_24", "vproattr_25",
    "vproattr_26", "vproattr_27", "vproattr_28", "vproattr_29", "vproattr_30",
    "vproattr_31", "vproattr_32", "vproattr_33", "vproattr_34"
]

# %%
def match_overview_data_assign(json_dict):
    result = []

    for game in json_dict:
        match_dict = {
            'matchId': game['matchId'],
            'timestamp': datetime.datetime.utcfromtimestamp(game['timestamp']).strftime('%Y-%m-%d %H:%M:%S UTC'),
        }

        both_club_data = game['clubs']

        # Initialize team index
        team_index = 1

        # Iterate through team data directly
        for team_prefix, data in both_club_data.items():
            prefix = f'team_{team_index}'  # Create a dynamic prefix
            team_index += 1  # Increment team index for the next iteration

            for key, value in data.items():
                if key == 'details':
                    match_dict[f'{prefix}_{key}_name'] = value['name']
                    match_dict[f'{prefix}_{key}_clubId'] = str(value['clubId'])
                    match_dict[f'{prefix}_{key}_regionId'] = str(value['regionId'])
                    match_dict[f'{prefix}_{key}_teamId'] = str(value['teamId'])
                    match_dict[f'{prefix}_{key}_stadName'] = value['customKit']['stadName']
#                     match_dict[f'{prefix}_{key}_isCustomTeam'] = str(value['customKit']['isCustomTeam'])
                else:
                    match_dict[f'{prefix}_{key}'] = str(value)

        result.append(match_dict)

    return result

# %%
def extract_cosmetic_data(data_list):
    club_data_dict = {}  # Dictionary to store data for each club

    for match in data_list:
        keys = list(match["clubs"].keys())

        for key in keys:
            club_data = {
                'clubId': int(key),
                'timestamp': datetime.datetime.fromtimestamp(int(match['timestamp'])),
                'name': match['clubs'][key]['details']['name'],
                'regionId': int(match['clubs'][key]['details']['regionId']),
                'teamId': int(match['clubs'][key]['details']['teamId']),
                **match['clubs'][key]['details']['customKit'],  # Include all customKit values
            }

            # Convert as many values as possible to integers
            for k, v in club_data.items():
                if k not in ["name", "stadName"]:
                    try:
                        club_data[k] = int(v)
                    except (ValueError, TypeError):
                        pass

            # Check if the clubId already exists in club_data_dict and if the new data has a newer timestamp
            if key in club_data_dict:
                existing_timestamp = club_data_dict[key]['timestamp']
                if club_data['timestamp'] > existing_timestamp:
                    club_data_dict[key] = club_data
            else:
                club_data_dict[key] = club_data

    # Convert the values in club_data_dict to a list
    custom_kit_data_list = list(club_data_dict.values())

    return custom_kit_data_list

# %%
def player_data_collect(data_list):
    aggregate_data_list = []

    for match in data_list:
        keys = list(match["clubs"].keys())
        team_1_data = {
            'matchId': int(match["matchId"]),
            'teamId': int(keys[0]),
        }
        team_2_data = {
            'matchId': int(match["matchId"]),
            'teamId': int(keys[1]),
        }

        # Create lists to store player data for each team
        team_1_players_data = []
        team_2_players_data = []

        # Generate list of Team 1 players
        team_1_players = list(match["players"][keys[0]].keys())

        # Generate list of Team 2 players
        team_2_players = list(match["players"][keys[1]].keys())

        # Add key-value pairs from match["players"][keys[0]] to team_1_data
        for player_id, player_data in match["players"][keys[0]].items():
            player_data_dict = {
                "playerId": int(player_id),
            }
            for key, value in player_data.items():
                # Convert to integer if value can be converted and key is not "playername"
                if value.isdigit() and key != "playername":
                    player_data_dict[key] = int(value)
                else:
                    player_data_dict[key] = value
            team_1_players_data.append(player_data_dict)

        # Add key-value pairs from match["players"][keys[1]] to team_2_data
        for player_id, player_data in match["players"][keys[1]].items():
            player_data_dict = {
                "playerId": int(player_id),
            }
            for key, value in player_data.items():
                # Convert to integer if value can be converted and key is not "playername"
                if value.isdigit() and key != "playername":
                    player_data_dict[key] = int(value)
                else:
                    player_data_dict[key] = value
            team_2_players_data.append(player_data_dict)

        aggregate_data_list.extend(team_1_players_data)
        aggregate_data_list.extend(team_2_players_data)

    return aggregate_data_list

# %%
def player_build_attributes(data_list, vproattr_key_names):
    vproattr_data_list = []

    for match in data_list:
        keys = list(match["clubs"].keys())

        # Team IDs
        team1_id = int(keys[0])
        team2_id = int(keys[1])

        # Iterate through players in Team 1
        for player_id, player_data in match["players"][keys[0]].items():
            game_id = int(match["matchId"])
            player_id = int(player_id)
            vproattr_values = player_data.get("vproattr", "").split("|")
            vproattr_values = [int(value) for value in vproattr_values if value.isdigit()]

            # Create a dictionary with keys for each vproattr value
            vproattr_data = {
                "gameId": game_id,
                "playerId": player_id,
                "teamId": team1_id,  # Add the team ID here
            }

            # Add vproattr values with user-defined key names
            for i, key_name in enumerate(vproattr_key_names):
                if i < len(vproattr_values):
                    vproattr_data[key_name] = vproattr_values[i]

            vproattr_data_list.append(vproattr_data)

        # Iterate through players in Team 2
        for player_id, player_data in match["players"][keys[1]].items():
            game_id = int(match["matchId"])
            player_id = int(player_id)
            vproattr_values = player_data.get("vproattr", "").split("|")
            vproattr_values = [int(value) for value in vproattr_values if value.isdigit()]

            # Create a dictionary with keys for each vproattr value
            vproattr_data = {
                "gameId": game_id,
                "playerId": player_id,
                "teamId": team2_id,  # Add the team ID here
            }

            # Add vproattr values with user-defined key names
            for i, key_name in enumerate(vproattr_key_names):
                if i < len(vproattr_values):
                    vproattr_data[key_name] = vproattr_values[i]

            vproattr_data_list.append(vproattr_data)

    return vproattr_data_list

# %%
# Initialize variables to track progress
total_rows = len(leaderboard_df)
successful_scrapes = 0
failed_scrapes = 0
failed_rows = []

# Iterate through the rows of leaderboard_df
for index, row in leaderboard_df.iterrows():
    # Construct the URL based on clubId and platform
    club_id = row['clubId']
    platform = row['platform']
    url = f"https://proclubs.ea.com/api/fc/clubs/matches?matchType=leagueMatch&platform={platform}&clubIds={club_id}"

    try:
        browser.visit(url)
        site = soup(browser.html, "html.parser")

        # Find the <pre> tag containing the JSON data
        pre_tag = site.find('pre')

        if pre_tag:
            # Extract the JSON data from the <pre> tag
            json_data = pre_tag.text

            # Convert JSON to a Python dictionary
            json_dict = json.loads(json_data)

            # Extract the broad match data and extend the list
            match_overview_dictionary_list.extend(match_overview_data_assign(json_dict))

            # Increment the successful scrape count
            successful_scrapes += 1

        # Add a one-second pause
        time.sleep(1)

    except Exception as e:
        failed_scrapes += 1
        failed_rows.append(index)
        print(f"\rFailed to scrape row {index}: {str(e)}", end="")
        sys.stdout.flush()

    # Print progress with carriage return to overwrite previous line
    progress_msg = f"Scraping progress: {successful_scrapes} out of {total_rows} complete, {failed_scrapes} failed"
    print(f"\r{progress_msg}", end="")
    sys.stdout.flush()

# Now, match_overview_dictionary contains match data from all the URLs in leaderboard_df
print()  # Print a newline to separate the progress from subsequent output
# Out:
# Scraping progress: 10 out of 10 complete, 0 failed

# %%
browser.quit()

# %%
duck = match_overview_data_assign(json_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22176\2610892976.py in <module>
# ----> 1 duck = match_overview_data_assign(json_dict)
#
# ~\AppData\Local\Temp\ipykernel_22176\984141117.py in match_overview_data_assign(json_dict)
#      25                     match_dict[f'{prefix}_{key}_teamId'] = str(value['teamId'])
#      26                     match_dict[f'{prefix}_{key}_stadName'] = value['customKit']['stadName']
# ---> 27                     match_dict[f'{prefix}_{key}_isCustomTeam'] = str(value['customKit']['isCustomTeam'])
#      28                 else:
#      29                     match_dict[f'{prefix}_{key}'] = str(value)
#
# KeyError: 'isCustomTeam'

# %%
json_dict
# Out:
# [{'matchId': '4138137480351',
#   'timestamp': 1696194485,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'28206': {'date': '1696194483',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '6',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '99160125',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'UNITED  LEGENDS',
#      'clubId': 28206,
#      'regionId': 4539733,
#      'teamId': 327,
#      'customKit': {'stadName': 'Legends Arena',
#       'kitId': '2678785',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '1',
#       'customKitId': '7663',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7645',
#       'customKeeperKitId': '5003',
#       'kitColor1': '7122142',
#       'kitColor2': '1256053',
#       'kitColor3': '1256053',
#       'kitColor4': '14655653',
#       'kitAColor1': '592397',
#       'kitAColor2': '7192366',
#       'kitAColor3': '7192366',
#       'kitAColor4': '7192366',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '1841428',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '1',
#       'crestColor': '-1',
#       'crestAssetId': '99160125'}}},
#    '639456': {'date': '1696194483',
#     'gameNumber': '0',
#     'goals': '6',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '6',
#     'season_id': '0',
#     'TEAM': '99160101',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'Grassbox FC',
#      'clubId': 639456,
#      'regionId': 4344147,
#      'teamId': 10,
#      'customKit': {'stadName': 'MKM Stadium',
#       'kitId': '81920',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7616',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5008',
#       'kitColor1': '592397',
#       'kitColor2': '7719080',
#       'kitColor3': '592397',
#       'kitColor4': '1909296',
#       'kitAColor1': '592397',
#       'kitAColor2': '1909296',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '7192366',
#       'kitThrdColor2': '858211',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '10066329',
#       'dCustomKit': '1',
#       'crestColor': '0',
#       'crestAssetId': '99160101'}}}},
#   'players': {'28206': {'172190537': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '9',
#      'passesmade': '8',
#      'pos': 'midfielder',
#      'rating': '6.40',
#      'realtimegame': '995',
#      'realtimeidle': '8',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '7',
#      'tacklesmade': '4',
#      'vproattr': '071|077|066|073|081|091|084|089|084|086|095|067|084|078|076|067|071|072|083|090|090|096|076|075|096|090|064|068|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'DiptwO'},
#     '172828931': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'defender',
#      'rating': '7.40',
#      'realtimegame': '6957',
#      'realtimeidle': '24',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '090|093|073|080|076|079|078|085|069|088|060|085|074|084|074|082|096|088|075|069|081|053|094|093|056|049|087|082|089|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'babdu'},
#     '196040708': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '6',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'XLM-tata1136'},
#     '1861086522': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '6.60',
#      'realtimegame': '10076',
#      'realtimeidle': '55',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|089|088|086|067|077|059|085|062|085|064|092|076|091|079|091|089|078|059|067|081|052|076|081|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'xClockCleaner91x'},
#     '1909266038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '18',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '6.00',
#      'realtimegame': '4007',
#      'realtimeidle': '5',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '9',
#      'tacklesmade': '1',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Berberrr030'},
#     '1004167635707': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '6',
#      'passesmade': '4',
#      'pos': 'defender',
#      'rating': '6.00',
#      'realtimegame': '995',
#      'realtimeidle': '26',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '10',
#      'tacklesmade': '2',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'KingSiff21'},
#     '1005741635345': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '9',
#      'pos': 'midfielder',
#      'rating': '5.90',
#      'realtimegame': '4202',
#      'realtimeidle': '66',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '7',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'THeIVcrusade22'},
#     '1006103165969': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '6',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'defender',
#      'rating': '6.90',
#      'realtimegame': '995',
#      'realtimeidle': '40',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '2',
#      'tackleattempts': '12',
#      'tacklesmade': '3',
#      'vproattr': '081|090|059|062|082|076|087|084|090|087|079|064|069|070|070|060|067|060|083|070|075|085|070|070|080|082|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'SiR00MiLeS1220'}},
#    '639456': {'367952031': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '9',
#      'passesmade': '8',
#      'pos': 'defender',
#      'rating': '8.30',
#      'realtimegame': '995',
#      'realtimeidle': '29',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '1',
#      'tackleattempts': '4',
#      'tacklesmade': '1',
#      'vproattr': '081|093|058|063|083|075|095|082|090|087|084|064|068|070|070|060|067|059|083|072|076|093|071|070|092|090|065|065|066|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Twinify'},
#     '381943496': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '19',
#      'passesmade': '16',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '995',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '3',
#      'tackleattempts': '6',
#      'tacklesmade': '1',
#      'vproattr': '080|088|082|072|074|083|080|084|079|085|071|082|084|080|080|089|090|081|074|082|083|080|083|088|077|076|079|076|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AAppleBY'},
#     '922989059': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '5',
#      'passesmade': '5',
#      'pos': 'defender',
#      'rating': '7.80',
#      'realtimegame': '995',
#      'realtimeidle': '21',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '2',
#      'tackleattempts': '5',
#      'tacklesmade': '0',
#      'vproattr': '082|093|060|063|084|076|084|082|085|087|086|064|069|070|070|062|068|060|082|071|076|093|069|069|089|093|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'EAppleby1'},
#     '1294901292': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '13',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '7.70',
#      'realtimegame': '995',
#      'realtimeidle': '25',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '3',
#      'tackleattempts': '9',
#      'tacklesmade': '2',
#      'vproattr': '083|091|071|074|078|090|077|085|077|085|074|075|086|081|084|077|087|086|071|082|083|078|084|087|075|074|077|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'B96162'},
#     '1815925083': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '2',
#      'passattempts': '19',
#      'passesmade': '14',
#      'pos': 'midfielder',
#      'rating': '9.60',
#      'realtimegame': '995',
#      'realtimeidle': '102',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '2',
#      'tackleattempts': '3',
#      'tacklesmade': '0',
#      'vproattr': '098|095|088|086|067|077|059|085|062|085|064|078|076|084|079|085|084|078|059|067|081|052|067|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'BillMount'},
#     '1846545508': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.00',
#      'realtimegame': '62703',
#      'realtimeidle': '21',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '1',
#      'playername': 'Meddy205'},
#     '1005033589289': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '14',
#      'passesmade': '12',
#      'pos': 'forward',
#      'rating': '9.50',
#      'realtimegame': '67633',
#      'realtimeidle': '1',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '6',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '088|089|065|074|073|078|079|083|074|089|060|085|076|077|073|075|097|078|077|070|081|056|085|084|053|046|087|075|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'joshfifaacc'}}},
#   'aggregate': {'28206': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 36,
#     'losses': 8,
#     'mom': 0,
#     'namespace': 8,
#     'passattempts': 73,
#     'passesmade': 54,
#     'pos': 0,
#     'rating': 48.2,
#     'realtimegame': 28227,
#     'realtimeidle': 224,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 8,
#     'shots': 2,
#     'tackleattempts': 51,
#     'tacklesmade': 10,
#     'vproattr': 0,
#     'vprohackreason': 32,
#     'wins': 0},
#    '639456': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 6,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 14,
#     'passattempts': 79,
#     'passesmade': 67,
#     'pos': 0,
#     'rating': 56.9,
#     'realtimegame': 135311,
#     'realtimeidle': 199,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 42,
#     'shots': 13,
#     'tackleattempts': 29,
#     'tacklesmade': 4,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 7}}},
#  {'matchId': '4114185540049',
#   'timestamp': 1696193350,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'422346': {'date': '1696193349',
#     'gameNumber': '0',
#     'goals': '0',
#     'goalsAgainst': '3',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '0',
#     'season_id': '0',
#     'TEAM': '99150508',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'FC Nonante',
#      'clubId': 422346,
#      'regionId': 5457237,
#      'teamId': 219,
#      'customKit': {'stadName': 'El Alcoraz',
#       'kitId': '1794048',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7534',
#       'customAwayKitId': '7648',
#       'customThirdKitId': '7631',
#       'customKeeperKitId': '5000',
#       'kitColor1': '592397',
#       'kitColor2': '8654629',
#       'kitColor3': '8654629',
#       'kitColor4': '15921906',
#       'kitAColor1': '7719080',
#       'kitAColor2': '592397',
#       'kitAColor3': '592397',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '14655653',
#       'kitThrdColor2': '8654629',
#       'kitThrdColor3': '8654629',
#       'kitThrdColor4': '592397',
#       'dCustomKit': '0',
#       'crestColor': '13179675',
#       'crestAssetId': '99150508'}}},
#    '639456': {'date': '1696193349',
#     'gameNumber': '0',
#     'goals': '3',
#     'goalsAgainst': '0',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '3',
#     'season_id': '0',
#     'TEAM': '99160101',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'Grassbox FC',
#      'clubId': 639456,
#      'regionId': 4344147,
#      'teamId': 10,
#      'customKit': {'stadName': 'MKM Stadium',
#       'kitId': '81920',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7616',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5008',
#       'kitColor1': '592397',
#       'kitColor2': '7719080',
#       'kitColor3': '592397',
#       'kitColor4': '1909296',
#       'kitAColor1': '592397',
#       'kitAColor2': '1909296',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '7192366',
#       'kitThrdColor2': '858211',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '10066329',
#       'dCustomKit': '1',
#       'crestColor': '0',
#       'crestAssetId': '99160101'}}}},
#   'players': {'422346': {'179750775': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '3',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '39',
#      'passesmade': '37',
#      'pos': 'midfielder',
#      'rating': '7.10',
#      'realtimegame': '887',
#      'realtimeidle': '4',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '6',
#      'tacklesmade': '2',
#      'vproattr': '083|091|077|074|078|085|077|085|077|085|074|082|083|088|082|077|079|081|071|082|083|078|080|082|075|074|071|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'smgd'},
#     '1784578244': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'defender',
#      'rating': '5.80',
#      'realtimegame': '4904',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '083|091|077|076|078|090|077|089|077|085|074|082|083|088|082|077|074|081|071|082|083|078|075|082|075|074|071|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'Ngomax'},
#     '1994115614': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '3',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '18',
#      'passesmade': '15',
#      'pos': 'forward',
#      'rating': '6.20',
#      'realtimegame': '8051',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '12',
#      'tacklesmade': '3',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'nesquiicky'}},
#    '639456': {'367952031': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '1',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '5',
#      'passesmade': '5',
#      'pos': 'defender',
#      'rating': '6.90',
#      'realtimegame': '887',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '081|093|058|063|083|075|095|082|090|087|084|064|068|070|070|060|067|059|083|072|076|093|071|070|092|090|065|065|066|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Twinify'},
#     '381943496': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '21',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '8.70',
#      'realtimegame': '887',
#      'realtimeidle': '3',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '1',
#      'vproattr': '080|088|082|072|074|083|080|084|079|085|071|082|084|080|080|089|090|081|074|082|083|080|083|088|077|076|079|076|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AAppleBY'},
#     '922989059': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '1',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '9',
#      'passesmade': '9',
#      'pos': 'defender',
#      'rating': '7.00',
#      'realtimegame': '887',
#      'realtimeidle': '15',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '082|093|060|063|084|076|084|082|085|087|086|064|069|070|070|062|068|060|082|071|076|093|069|069|089|093|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'EAppleby1'},
#     '1294901292': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '2',
#      'passattempts': '20',
#      'passesmade': '18',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '887',
#      'realtimeidle': '15',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '16',
#      'tacklesmade': '1',
#      'vproattr': '083|091|071|074|078|090|077|085|077|085|074|075|086|081|084|077|087|086|071|082|083|078|084|087|075|074|077|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'B96162'},
#     '1815925083': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '21',
#      'passesmade': '17',
#      'pos': 'midfielder',
#      'rating': '7.70',
#      'realtimegame': '887',
#      'realtimeidle': '60',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '2',
#      'tackleattempts': '7',
#      'tacklesmade': '1',
#      'vproattr': '098|095|088|086|067|077|059|085|062|085|064|078|076|084|079|085|084|078|059|067|081|052|067|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'BillMount'},
#     '1846545508': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '1',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '15',
#      'passesmade': '14',
#      'pos': 'defender',
#      'rating': '7.20',
#      'realtimegame': '887',
#      'realtimeidle': '75',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '1',
#      'playername': 'Meddy205'},
#     '1005033589289': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '18',
#      'passesmade': '15',
#      'pos': 'forward',
#      'rating': '8.50',
#      'realtimegame': '887',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '3',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '088|089|065|074|073|078|079|083|074|089|060|085|076|077|073|075|097|078|077|070|081|056|085|084|053|046|087|075|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'joshfifaacc'}}},
#   'aggregate': {'422346': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 6,
#     'losses': 3,
#     'mom': 0,
#     'namespace': 3,
#     'passattempts': 57,
#     'passesmade': 52,
#     'pos': 0,
#     'rating': 19.1,
#     'realtimegame': 13842,
#     'realtimeidle': 10,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 0,
#     'shots': 0,
#     'tackleattempts': 18,
#     'tacklesmade': 5,
#     'vproattr': 0,
#     'vprohackreason': 16,
#     'wins': 0},
#    '639456': {'assists': 3,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 3,
#     'cleansheetsgk': 0,
#     'goals': 3,
#     'goalsconceded': 0,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 14,
#     'passattempts': 109,
#     'passesmade': 98,
#     'pos': 0,
#     'rating': 55.0,
#     'realtimegame': 6209,
#     'realtimeidle': 186,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 21,
#     'shots': 10,
#     'tackleattempts': 28,
#     'tacklesmade': 5,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 7}}},
#  {'matchId': '4008538810075',
#   'timestamp': 1696187018,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'127646': {'date': '1696187017',
#     'gameNumber': '0',
#     'goals': '2',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '2',
#     'season_id': '0',
#     'TEAM': '243',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': '321 Team',
#      'clubId': 127646,
#      'regionId': 4344147,
#      'teamId': 243,
#      'customKit': {'stadName': 'Tier 2 Stadium',
#       'kitId': '1990656',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160322'}}},
#    '639456': {'date': '1696187017',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '2',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '99160101',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'Grassbox FC',
#      'clubId': 639456,
#      'regionId': 4344147,
#      'teamId': 10,
#      'customKit': {'stadName': 'MKM Stadium',
#       'kitId': '81920',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7616',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5008',
#       'kitColor1': '592397',
#       'kitColor2': '7719080',
#       'kitColor3': '592397',
#       'kitColor4': '1909296',
#       'kitAColor1': '592397',
#       'kitAColor2': '1909296',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '7192366',
#       'kitThrdColor2': '858211',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '10066329',
#       'dCustomKit': '1',
#       'crestColor': '0',
#       'crestAssetId': '99160101'}}}},
#   'players': {'127646': {'240339550': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '3',
#      'passesmade': '3',
#      'pos': 'midfielder',
#      'rating': '5.30',
#      'realtimegame': '991',
#      'realtimeidle': '384',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '0',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'DEAD OPS 911'},
#     '771017316': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '17',
#      'passesmade': '9',
#      'pos': 'forward',
#      'rating': '7.60',
#      'realtimegame': '112383',
#      'realtimeidle': '21',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '094|083|082|079|071|077|074|085|067|088|060|089|073|082|071|083|095|078|072|065|080|051|079|086|058|051|085|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'JSLTR'},
#     '1473889773': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '20',
#      'passesmade': '18',
#      'pos': 'forward',
#      'rating': '7.10',
#      'realtimegame': '12359',
#      'realtimeidle': '11',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'LJVLJ'},
#     '1769737179': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '25',
#      'passesmade': '18',
#      'pos': 'midfielder',
#      'rating': '7.80',
#      'realtimegame': '991',
#      'realtimeidle': '3',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '1',
#      'tackleattempts': '8',
#      'tacklesmade': '2',
#      'vproattr': '088|096|085|082|080|091|077|085|073|083|064|086|080|084|086|085|078|081|068|078|081|069|077|077|066|063|075|078|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'FirBeano'}},
#    '639456': {'367952031': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '11',
#      'passesmade': '10',
#      'pos': 'defender',
#      'rating': '8.30',
#      'realtimegame': '991',
#      'realtimeidle': '19',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '081|093|058|063|083|075|095|082|090|087|084|064|068|070|070|060|067|059|083|072|076|093|071|070|092|090|065|065|066|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Twinify'},
#     '381943496': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '23',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '8.80',
#      'realtimegame': '991',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '4',
#      'tacklesmade': '2',
#      'vproattr': '080|088|082|072|074|083|080|084|079|085|071|082|084|078|080|089|090|081|074|082|083|080|083|088|077|076|079|076|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AAppleBY'},
#     '922989059': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '6',
#      'passesmade': '3',
#      'pos': 'defender',
#      'rating': '6.20',
#      'realtimegame': '991',
#      'realtimeidle': '24',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '5',
#      'tacklesmade': '0',
#      'vproattr': '082|093|060|063|084|076|084|082|085|087|086|064|069|070|070|062|068|060|082|071|076|093|069|069|089|093|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'EAppleby1'},
#     '929279456': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '13',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '7.20',
#      'realtimegame': '37001',
#      'realtimeidle': '5',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '083|091|073|074|078|085|077|085|077|085|078|075|083|081|082|077|074|081|071|082|089|080|075|082|079|077|071|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Kz Youngyyy'},
#     '1294901292': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '3',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '2',
#      'passattempts': '18',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '9.50',
#      'realtimegame': '991',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '7',
#      'tackleattempts': '9',
#      'tacklesmade': '1',
#      'vproattr': '083|091|071|074|078|090|077|085|077|085|074|075|086|081|084|077|087|086|071|082|083|078|084|087|075|074|077|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'B96162'},
#     '1815925083': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '27',
#      'passesmade': '21',
#      'pos': 'midfielder',
#      'rating': '8.20',
#      'realtimegame': '991',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|084|086|067|077|059|085|062|085|064|078|076|084|079|087|084|078|059|067|081|052|067|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'BillMount'},
#     '1846545508': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '12',
#      'passesmade': '10',
#      'pos': 'defender',
#      'rating': '7.20',
#      'realtimegame': '991',
#      'realtimeidle': '47',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '1',
#      'playername': 'Meddy205'},
#     '1005033589289': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '16',
#      'passesmade': '15',
#      'pos': 'forward',
#      'rating': '7.30',
#      'realtimegame': '992',
#      'realtimeidle': '7',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '4',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '088|089|065|074|073|078|079|083|074|089|060|085|076|077|073|075|097|078|077|070|079|056|085|084|053|046|087|075|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'joshfifaacc'}}},
#   'aggregate': {'127646': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 2,
#     'goalsconceded': 16,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 8,
#     'passattempts': 65,
#     'passesmade': 48,
#     'pos': 0,
#     'rating': 27.8,
#     'realtimegame': 126724,
#     'realtimeidle': 419,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 8,
#     'shots': 4,
#     'tackleattempts': 12,
#     'tacklesmade': 2,
#     'vproattr': 0,
#     'vprohackreason': 16,
#     'wins': 0},
#    '639456': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 16,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 16,
#     'passattempts': 126,
#     'passesmade': 102,
#     'pos': 0,
#     'rating': 62.7,
#     'realtimegame': 43939,
#     'realtimeidle': 146,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 32,
#     'shots': 18,
#     'tackleattempts': 26,
#     'tacklesmade': 4,
#     'vproattr': 0,
#     'vprohackreason': 56,
#     'wins': 8}}},
#  {'matchId': '4004490490257',
#   'timestamp': 1696185892,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'473351': {'date': '1696185890',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '1799',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'MiravsKittens',
#      'clubId': 473351,
#      'regionId': 4344147,
#      'teamId': 1799,
#      'customKit': {'stadName': 'El Alcoraz',
#       'kitId': '14737411',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160114'}}},
#    '639456': {'date': '1696185890',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '99160101',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'Grassbox FC',
#      'clubId': 639456,
#      'regionId': 4344147,
#      'teamId': 10,
#      'customKit': {'stadName': 'MKM Stadium',
#       'kitId': '81920',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7616',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5008',
#       'kitColor1': '592397',
#       'kitColor2': '7719080',
#       'kitColor3': '592397',
#       'kitColor4': '1909296',
#       'kitAColor1': '592397',
#       'kitAColor2': '1909296',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '7192366',
#       'kitThrdColor2': '858211',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '10066329',
#       'dCustomKit': '1',
#       'crestColor': '0',
#       'crestAssetId': '99160101'}}}},
#   'players': {'639456': {'367952031': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '3',
#      'passesmade': '2',
#      'pos': 'defender',
#      'rating': '6.40',
#      'realtimegame': '28718',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '081|093|058|063|083|075|095|082|090|087|084|064|068|070|070|060|067|059|083|072|076|093|071|070|092|090|065|065|066|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Twinify'},
#     '381943496': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '2',
#      'passattempts': '28',
#      'passesmade': '25',
#      'pos': 'midfielder',
#      'rating': '10.00',
#      'realtimegame': '1039',
#      'realtimeidle': '5',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '7',
#      'tacklesmade': '5',
#      'vproattr': '080|088|082|072|074|083|080|084|079|085|071|082|084|078|080|089|090|081|074|082|083|080|083|088|077|076|079|076|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AAppleBY'},
#     '922989059': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '4',
#      'passesmade': '3',
#      'pos': 'defender',
#      'rating': '6.80',
#      'realtimegame': '1039',
#      'realtimeidle': '30',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '2',
#      'tacklesmade': '2',
#      'vproattr': '082|093|060|063|084|076|084|082|085|087|086|064|069|070|070|062|068|060|082|071|076|093|069|069|089|093|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'EAppleby1'},
#     '929279456': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '20',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '8.00',
#      'realtimegame': '35873',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '3',
#      'tacklesmade': '2',
#      'vproattr': '083|091|073|074|078|085|077|085|077|085|078|075|083|081|082|077|074|081|071|082|089|080|075|082|079|077|071|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Kz Youngyyy'},
#     '1294901292': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '19',
#      'passesmade': '14',
#      'pos': 'midfielder',
#      'rating': '10.00',
#      'realtimegame': '1039',
#      'realtimeidle': '12',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '7',
#      'tackleattempts': '11',
#      'tacklesmade': '6',
#      'vproattr': '083|091|071|074|078|090|077|085|077|085|074|075|086|081|084|077|087|086|071|082|083|078|084|087|075|074|077|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'B96162'},
#     '1815925083': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '25',
#      'passesmade': '19',
#      'pos': 'midfielder',
#      'rating': '9.10',
#      'realtimegame': '153343',
#      'realtimeidle': '22',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '5',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|084|086|067|077|059|085|062|085|064|078|076|084|079|087|084|078|059|067|081|052|067|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'BillMount'},
#     '1846545508': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '9',
#      'passesmade': '9',
#      'pos': 'defender',
#      'rating': '7.10',
#      'realtimegame': '1039',
#      'realtimeidle': '74',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '1',
#      'playername': 'Meddy205'},
#     '1005033589289': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '21',
#      'passesmade': '20',
#      'pos': 'forward',
#      'rating': '9.00',
#      'realtimegame': '1039',
#      'realtimeidle': '51',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '4',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '088|089|065|074|073|078|079|083|074|089|060|085|076|077|073|075|097|078|077|070|079|056|085|084|053|046|087|075|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'joshfifaacc'}},
#    '473351': {'1748981223': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '12',
#      'passesmade': '9',
#      'pos': 'forward',
#      'rating': '6.40',
#      'realtimegame': '23592',
#      'realtimeidle': '27',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Jemerson7896'},
#     '1831865160': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '7',
#      'passesmade': '7',
#      'pos': 'goalkeeper',
#      'rating': '6.70',
#      'realtimegame': '1039',
#      'realtimeidle': '21',
#      'redcards': '0',
#      'saves': '11',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '045|053|039|052|067|049|053|085|040|060|020|020|045|022|025|017|020|020|015|040|040|020|057|015|020|020|015|030|035|092|096|085|098|096|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'REINHARDTKING909'},
#     '1994090654': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'goalkeeper',
#      'rating': '5.70',
#      'realtimegame': '7066',
#      'realtimeidle': '27',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Sweat_Vardy0999'},
#     '1003939203536': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '5',
#      'passesmade': '4',
#      'pos': 'midfielder',
#      'rating': '6.00',
#      'realtimegame': '1039',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '8',
#      'tacklesmade': '2',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Optic-OMW'},
#     '1005336920807': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '21',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '6.70',
#      'realtimegame': '7516',
#      'realtimeidle': '26',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'RNRushabh'},
#     '1006503570870': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '8',
#      'passesmade': '7',
#      'pos': 'midfielder',
#      'rating': '6.90',
#      'realtimegame': '1039',
#      'realtimeidle': '11',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '2',
#      'tackleattempts': '5',
#      'tacklesmade': '1',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Yxng arch'},
#     '1007458780056': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '6.30',
#      'realtimegame': '1039',
#      'realtimeidle': '51',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '1',
#      'tackleattempts': '9',
#      'tacklesmade': '1',
#      'vproattr': '091|089|078|073|073|089|067|085|073|081|085|077|077|077|083|077|067|072|069|069|080|085|064|067|078|085|067|077|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'THEOBEAST8'}}},
#   'aggregate': {'639456': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 8,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 16,
#     'passattempts': 129,
#     'passesmade': 112,
#     'pos': 0,
#     'rating': 66.4,
#     'realtimegame': 223129,
#     'realtimeidle': 213,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 32,
#     'shots': 21,
#     'tackleattempts': 26,
#     'tacklesmade': 15,
#     'vproattr': 0,
#     'vprohackreason': 56,
#     'wins': 8},
#    '473351': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 1,
#     'goalsconceded': 24,
#     'losses': 7,
#     'mom': 0,
#     'namespace': 9,
#     'passattempts': 67,
#     'passesmade': 49,
#     'pos': 0,
#     'rating': 44.7,
#     'realtimegame': 42330,
#     'realtimeidle': 173,
#     'redcards': 0,
#     'saves': 11,
#     'SCORE': 7,
#     'shots': 3,
#     'tackleattempts': 26,
#     'tacklesmade': 4,
#     'vproattr': 0,
#     'vprohackreason': 16,
#     'wins': 0}}},
#  {'matchId': '3982466070325',
#   'timestamp': 1696184592,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'6416': {'date': '1696184591',
#     'gameNumber': '0',
#     'goals': '0',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '0',
#     'season_id': '0',
#     'TEAM': '99160118',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Tell Her FC',
#      'clubId': 6416,
#      'regionId': 4344147,
#      'teamId': 9,
#      'customKit': {'stadName': 'Estadio José Zorrilla',
#       'kitId': '73728',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '1',
#       'customKitId': '7629',
#       'customAwayKitId': '7634',
#       'customThirdKitId': '7526',
#       'customKeeperKitId': '5013',
#       'kitColor1': '14277081',
#       'kitColor2': '22436',
#       'kitColor3': '1256053',
#       'kitColor4': '14935011',
#       'kitAColor1': '16045584',
#       'kitAColor2': '1841428',
#       'kitAColor3': '16774144',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '592397',
#       'kitThrdColor2': '1841428',
#       'kitThrdColor3': '1841428',
#       'kitThrdColor4': '592397',
#       'dCustomKit': '0',
#       'crestColor': '0',
#       'crestAssetId': '99160118'}}},
#    '639456': {'date': '1696184591',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '0',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '99160101',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'Grassbox FC',
#      'clubId': 639456,
#      'regionId': 4344147,
#      'teamId': 10,
#      'customKit': {'stadName': 'MKM Stadium',
#       'kitId': '81920',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '1',
#       'customKitId': '7616',
#       'customAwayKitId': '7645',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5008',
#       'kitColor1': '592397',
#       'kitColor2': '7719080',
#       'kitColor3': '592397',
#       'kitColor4': '1909296',
#       'kitAColor1': '592397',
#       'kitAColor2': '1909296',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '7192366',
#       'kitThrdColor2': '858211',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '10066329',
#       'dCustomKit': '1',
#       'crestColor': '0',
#       'crestAssetId': '99160101'}}}},
#   'players': {'6416': {'195221404': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'forward',
#      'rating': '6.20',
#      'realtimegame': '835',
#      'realtimeidle': '29',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'CamS20Eze'},
#     '853867877': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '16',
#      'passesmade': '12',
#      'pos': 'forward',
#      'rating': '6.50',
#      'realtimegame': '840',
#      'realtimeidle': '4',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '1',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': '088|094|072|077|075|080|080|085|070|089|060|087|080|080|077|081|087|079|077|075|078|054|082|080|055|048|081|076|084|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ItsBrayzo'},
#     '909676544': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'defender',
#      'rating': '5.80',
#      'realtimegame': '11045',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'SonnyCals'},
#     '1298795049': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'forward',
#      'rating': '5.60',
#      'realtimegame': '141562',
#      'realtimeidle': '21',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '0',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'therealbrycey'}},
#    '639456': {'367952031': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '14',
#      'passesmade': '13',
#      'pos': 'defender',
#      'rating': '8.40',
#      'realtimegame': '840',
#      'realtimeidle': '16',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '081|093|058|063|083|075|095|082|090|087|084|064|068|070|070|060|067|059|083|072|076|093|071|070|092|090|065|065|066|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Twinify'},
#     '381943496': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '2',
#      'passattempts': '22',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '9.20',
#      'realtimegame': '840',
#      'realtimeidle': '4',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '080|088|082|072|074|083|080|084|079|085|071|082|084|078|080|089|090|081|074|082|083|080|083|088|077|076|079|076|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AAppleBY'},
#     '922989059': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '10',
#      'passesmade': '9',
#      'pos': 'defender',
#      'rating': '7.50',
#      'realtimegame': '840',
#      'realtimeidle': '20',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '082|093|060|063|084|076|084|082|085|087|086|064|069|070|070|062|068|060|082|071|076|093|069|069|089|093|063|065|065|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'EAppleby1'},
#     '929279456': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '22',
#      'passesmade': '18',
#      'pos': 'midfielder',
#      'rating': '8.60',
#      'realtimegame': '840',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '083|091|073|074|078|085|077|085|077|085|078|075|083|081|082|077|074|081|071|082|087|080|075|082|079|077|071|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'Kz Youngyyy'},
#     '1294901292': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '11',
#      'passesmade': '9',
#      'pos': 'midfielder',
#      'rating': '7.30',
#      'realtimegame': '840',
#      'realtimeidle': '18',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '4',
#      'tacklesmade': '0',
#      'vproattr': '083|091|071|074|078|090|077|085|077|085|074|075|086|081|084|077|087|086|071|082|083|078|084|087|075|074|077|077|076|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'B96162'},
#     '1815925083': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '23',
#      'passesmade': '16',
#      'pos': 'midfielder',
#      'rating': '8.90',
#      'realtimegame': '840',
#      'realtimeidle': '18',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|084|086|067|077|059|085|062|085|064|078|076|084|079|085|084|078|059|067|081|052|067|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'BillMount'},
#     '1846545508': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '13',
#      'passesmade': '13',
#      'pos': 'defender',
#      'rating': '7.40',
#      'realtimegame': '840',
#      'realtimeidle': '49',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '5',
#      'tacklesmade': '3',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '1',
#      'playername': 'Meddy205'},
#     '1005033589289': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '2',
#      'passattempts': '10',
#      'passesmade': '10',
#      'pos': 'forward',
#      'rating': '7.80',
#      'realtimegame': '50916',
#      'realtimeidle': '11',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|065|074|073|078|079|083|074|089|060|085|076|077|073|075|097|078|077|070|079|056|085|084|053|046|087|075|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'joshfifaacc'}}},
#   'aggregate': {'6416': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 4,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 8,
#     'passattempts': 16,
#     'passesmade': 12,
#     'pos': 0,
#     'rating': 24.1,
#     'realtimegame': 154282,
#     'realtimeidle': 63,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 0,
#     'shots': 1,
#     'tackleattempts': 3,
#     'tacklesmade': 1,
#     'vproattr': 0,
#     'vprohackreason': 8,
#     'wins': 0},
#    '639456': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 0,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 16,
#     'passattempts': 125,
#     'passesmade': 108,
#     'pos': 0,
#     'rating': 65.1,
#     'realtimegame': 56796,
#     'realtimeidle': 146,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 32,
#     'shots': 14,
#     'tackleattempts': 13,
#     'tacklesmade': 5,
#     'vproattr': 0,
#     'vprohackreason': 56,
#     'wins': 8}}}]

# %%
match_overview_dictionary_list
match_overview_dictionary_df = pd.DataFrame(match_overview_dictionary_list)
match_overview_dictionary_df
# Out:
#           matchId                timestamp team_1_date team_1_gameNumber  \
# 0   4114690610271  2023-10-01 21:43:29 UTC  1696196608                 0
# 1   4100888560230  2023-10-01 21:22:48 UTC  1696195367                 0
# 2   4102692080376  2023-10-01 21:13:28 UTC  1696194807                 0
# 3   4086908470332  2023-10-01 20:49:22 UTC  1696193361                 0
# 4   4098418620049  2023-10-01 20:26:49 UTC  1696192008                 0
# 5   4548899570082  2023-10-02 20:42:43 UTC  1696279361                 0
# 6   4564535850163  2023-10-02 20:22:18 UTC  1696278137                 0
# 7   4542116740183  2023-10-02 19:24:43 UTC  1696274682                 0
# 8   4532208650416  2023-10-02 19:00:03 UTC  1696273202                 0
# 9   4472752760346  2023-10-02 18:47:41 UTC  1696272460                 0
# 10  4580946670132  2023-10-02 21:39:54 UTC  1696282793                 0
# 11  4204794770344  2023-10-02 02:09:41 UTC  1696212579                 0
# 12  4228553840065  2023-10-02 01:46:04 UTC  1696211163                 0
# 13  4192837890329  2023-10-02 01:26:05 UTC  1696209964                 0
# 14  4210462780267  2023-10-02 00:36:51 UTC  1696207010                 0
# 15  3570324200463  2023-09-30 23:55:28 UTC  1696118126                 0
# 16  3574067600441  2023-09-30 23:33:00 UTC  1696116779                 0
# 17  3546495010119  2023-09-30 22:55:06 UTC  1696114505                 0
# 18  3492652100125  2023-09-30 22:33:46 UTC  1696113225                 0
# 19  3498419150227  2023-09-30 22:16:53 UTC  1696112212                 0
# 20  4382802120300  2023-10-02 16:26:52 UTC  1696264011                 0
# 21  4388659210069  2023-10-02 16:06:20 UTC  1696262779                 0
# 22  4436065870157  2023-10-02 15:42:47 UTC  1696261365                 0
# 23  4374353710137  2023-10-02 14:46:32 UTC  1696257991                 0
# 24  4228099740371  2023-10-01 23:31:26 UTC  1696203086                 0
# 25  4466327780427  2023-10-02 17:47:22 UTC  1696268842                 0
# 26  4444517270135  2023-10-02 17:30:38 UTC  1696267837                 0
# 27  4448245970256  2023-10-02 16:56:53 UTC  1696265812                 0
# 28  4362901200452  2023-10-02 16:05:20 UTC  1696262719                 0
# 29  4396415100400  2023-10-02 15:42:04 UTC  1696261323                 0
# 30  4660108020300  2023-10-02 21:43:52 UTC  1696283031                 0
# 31  4382420540395  2023-10-02 15:00:59 UTC  1696258858                 0
# 32  4404054020364  2023-10-02 14:50:27 UTC  1696258226                 0
# 33  4330729700242  2023-10-02 14:20:57 UTC  1696256456                 0
# 34  4386169470280  2023-10-02 14:11:31 UTC  1696255890                 0
# 35  4648138170428  2023-10-02 21:28:38 UTC  1696282117                 0
# 36  4216979880254  2023-10-02 04:17:37 UTC  1696220256                 0
# 37  4232744450209  2023-10-02 03:57:59 UTC  1696219078                 0
# 38  4214905760276  2023-10-02 03:32:48 UTC  1696217566                 0
# 39  4206925310377  2023-10-02 03:06:25 UTC  1696215984                 0
# 40  4642332210020  2023-10-02 21:44:09 UTC  1696283048                 0
# 41  3916923080074  2023-10-01 17:37:38 UTC  1696181857                 0
# 42  3934450910173  2023-10-01 17:10:13 UTC  1696180212                 0
# 43  3936125370312  2023-10-01 16:51:52 UTC  1696179111                 0
# 44  3916312750191  2023-10-01 16:14:43 UTC  1696176882                 0
# 45  4138137480351  2023-10-01 21:08:05 UTC  1696194483                 0
# 46  4114185540049  2023-10-01 20:49:10 UTC  1696193349                 0
# 47  4008538810075  2023-10-01 19:03:38 UTC  1696187017                 0
# 48  4004490490257  2023-10-01 18:44:52 UTC  1696185890                 0
# 49  3982466070325  2023-10-01 18:23:12 UTC  1696184591                 0
#
#    team_1_goals team_1_goalsAgainst team_1_losses team_1_matchType  \
# 0             5                   1             0                1
# 1             6                   1             0                1
# 2             3                   1             0                1
# 3             4                   0             0                1
# 4             3                   0             0                1
# 5             0                   0             0                1
# 6             5                   2             0                1
# 7             7                   4             0                1
# 8             3                   0             0                1
# 9             3                   0             0                1
# 10            2                   0             0                1
# 11            5                   2             0                1
# 12            2                   1             0                1
# 13            2                   1             0                1
# 14            4                   0             0                1
# 15            4                   3             0                1
# 16            6                   1             0                1
# 17            3                   2             0                1
# 18            4                   1             0                1
# 19            3                   1             0                1
# 20            4                   1             0                1
# 21            4                   1             0                1
# 22            3                   4             1                1
# 23            1                   3             1                1
# 24            4                   1             0                1
# 25            0                   3             1                1
# 26            6                   0             0                1
# 27            1                   4             1                1
# 28            1                   4             1                1
# 29            0                   0             0                1
# 30            0                   3             1                1
# 31            0                   3             1                1
# 32            3                   6             1                1
# 33            0                   3             1                1
# 34            0                   3             1                1
# 35            0                   0             0                1
# 36            1                   6             1                1
# 37            3                   0             0                1
# 38            1                   5             1                1
# 39            1                   2             1                1
# 40            2                   4             1                1
# 41            2                   5             1                1
# 42            0                   3             1                1
# 43            2                   4             1                1
# 44            5                   4             0                1
# 45            1                   6             1                1
# 46            0                   3             1                1
# 47            2                   4             1                1
# 48            1                   4             1                1
# 49            0                   4             1                1
#
#    team_1_result team_1_score  ... team_2_season_id team_2_TEAM team_2_ties  \
# 0              1            5  ...                0        1796           0
# 1          16385            6  ...                0    99070107           0
# 2              1            3  ...                0      101047           0
# 3              1            4  ...                0    99160416           0
# 4          16385            3  ...                0    99120101           0
# 5              4            0  ...                0        1876           1
# 6              1            5  ...                0         241           0
# 7              1            7  ...                0         243           0
# 8          16385            3  ...                0    99150507           0
# 9          16385            3  ...                0    99160429           0
# 10             1            2  ...                0         453           0
# 11             1            5  ...                0          13           0
# 12             1            2  ...                0        1824           0
# 13             1            2  ...                0        1335           0
# 14             1            4  ...                0         453           0
# 15             1            4  ...                0         240           0
# 16             1            6  ...                0      112893           0
# 17             1            3  ...                0        1799           0
# 18             1            4  ...                0    99160311           0
# 19             1            3  ...                0          22           0
# 20             1            4  ...                0         237           0
# 21             1            4  ...                0    99160115           0
# 22             2            3  ...                0    99160115           0
# 23             2            1  ...                0        1369           0
# 24         16385            4  ...                0         219           0
# 25            10            0  ...                0          13           0
# 26             1            6  ...                0          10           0
# 27             2            1  ...                0          13           0
# 28             2            1  ...                0          13           0
# 29             4            0  ...                0          13           1
# 30            10            0  ...                0      111473           0
# 31            10            0  ...                0      111473           0
# 32             2            3  ...                0      111473           0
# 33            10            0  ...                0      111473           0
# 34            10            0  ...                0      111473           0
# 35             4            0  ...                0         234           1
# 36             2            1  ...                0         234           0
# 37         16385            3  ...                0      111674           0
# 38             2            1  ...                0         234           0
# 39             2            1  ...                0         234           0
# 40             2            2  ...                0        1805           0
# 41             2            2  ...                0        1805           0
# 42            10            0  ...                0        1805           0
# 43             2            2  ...                0        1805           0
# 44             1            5  ...                0          92           0
# 45             2            1  ...                0    99160101           0
# 46             2            0  ...                0    99160101           0
# 47             2            2  ...                0    99160101           0
# 48             2            1  ...                0    99160101           0
# 49            10            0  ...                0    99160101           0
#
#    team_2_winnerByDnf team_2_wins team_2_details_name team_2_details_clubId  \
# 0                   0           0      DYCHES MINIONS                 21666
# 1                   0           0         The Casuals                136646
# 2                   0           0           S o N e 1                299396
# 3                   0           0          BARBARIANS                 83326
# 4                   0           0          Coda Bhoys                162911
# 5                   0           0             aln3jat                 20131
# 6                   0           0               M9zlf                 75566
# 7                   0           0               M N O               1026121
# 8                   0           0              MHRJEN                 29646
# 9                   0           0     Glens Gyat City                150701
# 10                  0           0         S i L E N T                 15121
# 11                  0           0         Victoria FC                 44671
# 12                  0           0               O P 7                 16601
# 13                  0           0           F e i n x                 16306
# 14                  0           0         S i L E N T                 15121
# 15                  0           0         Superkicker                275421
# 16                  0           0           fc united                 64971
# 17                  0           0      Class in Grass                 39226
# 18                  0           0          Makélélent                106531
# 19                  0           0               JUBA1                241251
# 20                  0           0     SNORTING LlSB0N                555451
# 21                  0           0             K H Z M                742591
# 22                  0           1             K H Z M                742591
# 23                  0           1               Fooll                536711
# 24                  0           0        3 B E E D FC                762031
# 25                  1           1           S M I L E                347426
# 26                  0           0      5leha 3Ia aIah                458576
# 27                  0           1           S M I L E                347426
# 28                  0           1           S M I L E                347426
# 29                  0           0           S M I L E                347426
# 30                  1           1              xFC24x                545151
# 31                  1           1              xFC24x                545151
# 32                  0           1              xFC24x                545151
# 33                  1           1              xFC24x                545151
# 34                  1           1              xFC24x                545151
# 35                  0           0             V A L E                526006
# 36                  0           1             V A L E                526006
# 37                  0           0            Vesports                725871
# 38                  0           1             V A L E                526006
# 39                  0           1             V A L E                526006
# 40                  0           1        MAFIA  GANGS                295561
# 41                  0           1        MAFIA  GANGS                295561
# 42                  1           1        MAFIA  GANGS                295561
# 43                  0           1        MAFIA  GANGS                295561
# 44                  0           0             Potatos                365256
# 45                  0           1         Grassbox FC                639456
# 46                  0           1         Grassbox FC                639456
# 47                  0           1         Grassbox FC                639456
# 48                  0           1         Grassbox FC                639456
# 49                  1           1         Grassbox FC                639456
#
#    team_2_details_regionId team_2_details_teamId  \
# 0                  4344147                  1796
# 1                  4344147                    19
# 2                  5064001                101047
# 3                  5064001                116311
# 4                  4344147                     1
# 5                  5064001                  1876
# 6                  5064001                   241
# 7                  5064001                     9
# 8                  5064001                   243
# 9                  4344147                    11
# 10                 5064001                   453
# 11                 5064001                113011
# 12                 5064001                  1824
# 13                 5064001                  1343
# 14                 5064001                   453
# 15                 4539733                   240
# 16                 4543827                112893
# 17                 5064001                  1799
# 18                 5457237                   243
# 19                 5064001                    22
# 20                 4344147                   237
# 21                 5064001                    73
# 22                 5064001                    73
# 23                 5064001                  1369
# 24                 5064001                   219
# 25                 5064001                    13
# 26                 5064001                    10
# 27                 5064001                    13
# 28                 5064001                    13
# 29                 5064001                    13
# 30                 5457237                111473
# 31                 5457237                111473
# 32                 5457237                111473
# 33                 5457237                111473
# 34                 5457237                111473
# 35                 5064001                   234
# 36                 5064001                   234
# 37                 5064001                111674
# 38                 5064001                   234
# 39                 5064001                   234
# 40                 5064001                  1805
# 41                 5064001                  1805
# 42                 5064001                  1805
# 43                 5064001                  1805
# 44                 4344147                    92
# 45                 4344147                    10
# 46                 4344147                    10
# 47                 4344147                    10
# 48                 4344147                    10
# 49                 4344147                    10
#
#            team_2_details_stadName
# 0                 Vitality Stadium
# 1                   Tier 1 Stadium
# 2                       El Alcoraz
# 3                    ملعب الدرجة 2
# 4                      SchücoArena
# 5   Sportpark Ronhof Thomas Sommer
# 6                       El Alcoraz
# 7                       El Alcoraz
# 8                         BC Place
# 9                         The Shed
# 10           Ramón Sánchez-Pizjuán
# 11                        BC Place
# 12           Ramón Sánchez-Pizjuán
# 13                      El Alcoraz
# 14           Ramón Sánchez-Pizjuán
# 15             Estadio de Vallecas
# 16                      El Alcoraz
# 17           Estadio José Zorrilla
# 18                  Stade niveau 2
# 19                      El Alcoraz
# 20           Estadio José Zorrilla
# 21         Estadio de Mendizorroza
# 22         Estadio de Mendizorroza
# 23                      El Alcoraz
# 24                     SchücoArena
# 25           Estadio José Zorrilla
# 26                Estadio El Sadar
# 27           Estadio José Zorrilla
# 28           Estadio José Zorrilla
# 29           Estadio José Zorrilla
# 30                      El Alcoraz
# 31                      El Alcoraz
# 32                      El Alcoraz
# 33                      El Alcoraz
# 34                      El Alcoraz
# 35                   ملعب الدرجة 1
# 36                   ملعب الدرجة 1
# 37                      El Alcoraz
# 38                   ملعب الدرجة 1
# 39                   ملعب الدرجة 1
# 40           Mercedes-Benz Stadium
# 41           Mercedes-Benz Stadium
# 42           Mercedes-Benz Stadium
# 43           Mercedes-Benz Stadium
# 44                      El Alcoraz
# 45                     MKM Stadium
# 46                     MKM Stadium
# 47                     MKM Stadium
# 48                     MKM Stadium
# 49                     MKM Stadium
#
# [50 rows x 38 columns]
