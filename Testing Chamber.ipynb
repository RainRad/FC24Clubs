# %%
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as soup
import datetime
import json
import requests
import sys
import time

# %%
leaderboard_df = pd.read_csv('T100Leaderboard.csv')
leaderboard_df = leaderboard_df[["clubId", "platform"]]
leaderboard_df.head(3)
leaderboard_df = leaderboard_df[0:10]
leaderboard_df
# Out:
#     clubId     platform
# 0  3084976  common-gen4
# 1    13791  common-gen4
# 2    16046  common-gen4
# 3    13541  common-gen4
# 4  2613056  common-gen4
# 5  3830521  common-gen4
# 6  3302026  common-gen4
# 7  2256236  common-gen4
# 8    17186  common-gen4
# 9   662486  common-gen4

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
match_overview_dictionary_list = []
player_build_stat_list = []
player_stat_list = []
club_cosmetic_list = []

# %%
vproattr_key_names = [
    "vproattr_1", "vproattr_2", "vproattr_3", "vproattr_4", "vproattr_5",
    "vproattr_6", "vproattr_7", "vproattr_8", "vproattr_9", "vproattr_10",
    "vproattr_11", "vproattr_12", "vproattr_13", "vproattr_14", "vproattr_15",
    "vproattr_16", "vproattr_17", "vproattr_18", "vproattr_19", "vproattr_20",
    "vproattr_21", "vproattr_22", "vproattr_23", "vproattr_24", "vproattr_25",
    "vproattr_26", "vproattr_27", "vproattr_28", "vproattr_29", "vproattr_30",
    "vproattr_31", "vproattr_32", "vproattr_33", "vproattr_34"
]

# %%
def match_overview_data_assign(json_dict):
    result = []

    for game in json_dict:
        match_dict = {
            'matchId': game['matchId'],
            'timestamp': datetime.datetime.utcfromtimestamp(game['timestamp']).strftime('%Y-%m-%d %H:%M:%S UTC'),
        }

        both_club_data = game['clubs']

        # Initialize team index
        team_index = 1

        # Iterate through team data directly
        for team_prefix, data in both_club_data.items():
            prefix = f'team_{team_index}'  # Create a dynamic prefix
            team_index += 1  # Increment team index for the next iteration

            for key, value in data.items():
                if key == 'details':
                    match_dict[f'{prefix}_{key}_name'] = value['name']
                    match_dict[f'{prefix}_{key}_clubId'] = str(value['clubId'])
                    match_dict[f'{prefix}_{key}_regionId'] = str(value['regionId'])
                    match_dict[f'{prefix}_{key}_teamId'] = str(value['teamId'])
                    match_dict[f'{prefix}_{key}_stadName'] = value['customKit']['stadName']
#                     match_dict[f'{prefix}_{key}_isCustomTeam'] = str(value['customKit']['isCustomTeam'])
                else:
                    match_dict[f'{prefix}_{key}'] = str(value)

        result.append(match_dict)

    return result

# %%
def extract_cosmetic_data(data_list):
    club_data_dict = {}  # Dictionary to store data for each club

    for match in data_list:
        keys = list(match["clubs"].keys())

        for key in keys:
            club_data = {
                'clubId': int(key),
                'timestamp': datetime.datetime.fromtimestamp(int(match['timestamp'])),
                'name': match['clubs'][key]['details']['name'],
                'regionId': int(match['clubs'][key]['details']['regionId']),
                'teamId': int(match['clubs'][key]['details']['teamId']),
                **match['clubs'][key]['details']['customKit'],  # Include all customKit values
            }

            # Convert as many values as possible to integers
            for k, v in club_data.items():
                if k not in ["name", "stadName"]:
                    try:
                        club_data[k] = int(v)
                    except (ValueError, TypeError):
                        pass

            # Check if the clubId already exists in club_data_dict and if the new data has a newer timestamp
            if key in club_data_dict:
                existing_timestamp = club_data_dict[key]['timestamp']
                if club_data['timestamp'] > existing_timestamp:
                    club_data_dict[key] = club_data
            else:
                club_data_dict[key] = club_data

    # Convert the values in club_data_dict to a list
    custom_kit_data_list = list(club_data_dict.values())

    return custom_kit_data_list

# %%
def player_data_collect(data_list):
    aggregate_data_list = []

    for match in data_list:
        keys = list(match["clubs"].keys())
        team_1_data = {
            'matchId': int(match["matchId"]),
            'teamId': int(keys[0]),
        }
        team_2_data = {
            'matchId': int(match["matchId"]),
            'teamId': int(keys[1]),
        }

        # Create lists to store player data for each team
        team_1_players_data = []
        team_2_players_data = []

        # Generate list of Team 1 players
        team_1_players = list(match["players"][keys[0]].keys())

        # Generate list of Team 2 players
        team_2_players = list(match["players"][keys[1]].keys())

        # Add key-value pairs from match["players"][keys[0]] to team_1_data
        for player_id, player_data in match["players"][keys[0]].items():
            player_data_dict = {
                'matchId': int(match["matchId"]),
                'teamId': int(keys[0]),
                "playerId": int(player_id),
            }
            for key, value in player_data.items():
                # Convert to integer if value can be converted and key is not "playername"
                if value.isdigit() and key != "playername":
                    player_data_dict[key] = int(value)
                else:
                    player_data_dict[key] = value
            team_1_players_data.append(player_data_dict)

        # Add key-value pairs from match["players"][keys[1]] to team_2_data
        for player_id, player_data in match["players"][keys[1]].items():
            player_data_dict = {
                'matchId': int(match["matchId"]),
                'teamId': int(keys[1]),
                "playerId": int(player_id),
            }
            for key, value in player_data.items():
                # Convert to integer if value can be converted and key is not "playername"
                if value.isdigit() and key != "playername":
                    player_data_dict[key] = int(value)
                else:
                    player_data_dict[key] = value
            team_2_players_data.append(player_data_dict)

        aggregate_data_list.extend(team_1_players_data)
        aggregate_data_list.extend(team_2_players_data)

    return aggregate_data_list

# %%
def player_build_attributes(data_list, vproattr_key_names):
    vproattr_data_list = []

    for match in data_list:
        keys = list(match["clubs"].keys())

        # Team IDs
        team1_id = int(keys[0])
        team2_id = int(keys[1])

        # Iterate through players in Team 1
        for player_id, player_data in match["players"][keys[0]].items():
            game_id = int(match["matchId"])
            player_id = int(player_id)
            vproattr_values = player_data.get("vproattr", "").split("|")
            vproattr_values = [int(value) for value in vproattr_values if value.isdigit()]

            # Create a dictionary with keys for each vproattr value
            vproattr_data = {
                "gameId": game_id,
                "playerId": player_id,
                "teamId": team1_id,  # Add the team ID here
            }

            # Add vproattr values with user-defined key names
            for i, key_name in enumerate(vproattr_key_names):
                if i < len(vproattr_values):
                    vproattr_data[key_name] = vproattr_values[i]

            vproattr_data_list.append(vproattr_data)

        # Iterate through players in Team 2
        for player_id, player_data in match["players"][keys[1]].items():
            game_id = int(match["matchId"])
            player_id = int(player_id)
            vproattr_values = player_data.get("vproattr", "").split("|")
            vproattr_values = [int(value) for value in vproattr_values if value.isdigit()]

            # Create a dictionary with keys for each vproattr value
            vproattr_data = {
                "gameId": game_id,
                "playerId": player_id,
                "teamId": team2_id,  # Add the team ID here
            }

            # Add vproattr values with user-defined key names
            for i, key_name in enumerate(vproattr_key_names):
                if i < len(vproattr_values):
                    vproattr_data[key_name] = vproattr_values[i]

            vproattr_data_list.append(vproattr_data)

    return vproattr_data_list

# %%
# Initialize variables to track progress
total_rows = len(leaderboard_df)
successful_scrapes = 0
failed_scrapes = 0
failed_rows = []

# Iterate through the rows of leaderboard_df
for index, row in leaderboard_df.iterrows():
    # Construct the URL based on clubId and platform
    club_id = row['clubId']
    platform = row['platform']
    url = f"https://proclubs.ea.com/api/fc/clubs/matches?matchType=leagueMatch&platform={platform}&clubIds={club_id}"

    try:
        browser.visit(url)
        site = soup(browser.html, "html.parser")

        # Find the <pre> tag containing the JSON data
        pre_tag = site.find('pre')

        if pre_tag:
            # Extract the JSON data from the <pre> tag
            json_data = pre_tag.text

            # Convert JSON to a Python dictionary
            json_dict = json.loads(json_data)

            # Extract the broad match data and extend the list
            match_overview_dictionary_list.extend(match_overview_data_assign(json_dict))
            player_build_stat_list.extend(player_build_attributes(json_dict, vproattr_key_names))
            player_stat_list.extend(player_data_collect(json_dict))
            club_cosmetic_list.extend(extract_cosmetic_data(json_dict))
            
            # Increment the successful scrape count
            successful_scrapes += 1

        # Add a one-second pause
        time.sleep(1)

    except Exception as e:
        failed_scrapes += 1
        failed_rows.append(index)
        print(f"\rFailed to scrape row {index}: {str(e)}", end="")
        sys.stdout.flush()

    # Print progress with carriage return to overwrite previous line
    progress_msg = f"Scraping progress: {successful_scrapes} out of {total_rows} complete, {failed_scrapes} failed"
    print(f"\r{progress_msg}", end="")
    sys.stdout.flush()

# Now, match_overview_dictionary contains match data from all the URLs in leaderboard_df
print()  # Print a newline to separate the progress from subsequent output
# Out:
# Scraping progress: 10 out of 10 complete, 0 failed

# %%
browser.quit()

# %%
club_cosmetic_list
# Out:
# [{'clubId': 26401,
#   'timestamp': datetime.datetime(2023, 11, 24, 1, 15, 10),
#   'name': 'H O  2',
#   'regionId': 5064001,
#   'teamId': 1,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 8195,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7703,
#   'customAwayKitId': 7627,
#   'customThirdKitId': 7627,
#   'customKeeperKitId': 5029,
#   'kitColor1': 592397,
#   'kitColor2': 14935011,
#   'kitColor3': 592397,
#   'kitColor4': 14935011,
#   'kitAColor1': 4920087,
#   'kitAColor2': 14277081,
#   'kitAColor3': 4920087,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 1482375,
#   'kitThrdColor2': 15921906,
#   'kitThrdColor3': 1482375,
#   'kitThrdColor4': 15921906,
#   'dCustomKit': 0,
#   'crestColor': 16777215,
#   'crestAssetId': 99060205},
#  {'clubId': 3084976,
#   'timestamp': datetime.datetime(2023, 11, 24, 1, 15, 10),
#   'name': 'Old Champions',
#   'regionId': 5064001,
#   'teamId': 18,
#   'stadName': 'Municipal de Ipurua',
#   'kitId': 147457,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160311},
#  {'clubId': 2590531,
#   'timestamp': datetime.datetime(2023, 11, 24, 0, 42, 39),
#   'name': 'Hâlæ Mädrid',
#   'regionId': 5064001,
#   'teamId': 11,
#   'stadName': 'Estadio de Mendizorroza',
#   'kitId': 90112,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 14935011,
#   'kitColor3': 4133724,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 3,
#   'crestColor': -1,
#   'crestAssetId': 99160317},
#  {'clubId': 2748486,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 51, 42),
#   'name': 'ÖMAN',
#   'regionId': 5064001,
#   'teamId': 114640,
#   'stadName': 'Ramón Sánchez-Pizjuán',
#   'kitId': 939130881,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 1,
#   'customKitId': 7601,
#   'customAwayKitId': 7703,
#   'customThirdKitId': 7630,
#   'customKeeperKitId': 5016,
#   'kitColor1': 14358546,
#   'kitColor2': 1336871,
#   'kitColor3': 15921906,
#   'kitColor4': 15921906,
#   'kitAColor1': 592397,
#   'kitAColor2': 5775459,
#   'kitAColor3': 5775459,
#   'kitAColor4': 5775459,
#   'kitThrdColor1': 15921906,
#   'kitThrdColor2': 14358546,
#   'kitThrdColor3': 1336871,
#   'kitThrdColor4': 14358546,
#   'dCustomKit': 3,
#   'crestColor': 13179675,
#   'crestAssetId': 99150508},
#  {'clubId': 4071716,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 31, 48),
#   'name': 'Coldplay',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Tier 1 Stadium',
#   'kitId': 918642688,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7522,
#   'customAwayKitId': 7636,
#   'customThirdKitId': 7629,
#   'customKeeperKitId': 5025,
#   'kitColor1': 15921906,
#   'kitColor2': 8237531,
#   'kitColor3': 7122142,
#   'kitColor4': 7122142,
#   'kitAColor1': 2704542,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 8237531,
#   'kitThrdColor2': 16464712,
#   'kitThrdColor3': 15921906,
#   'kitThrdColor4': 14358546,
#   'dCustomKit': 3,
#   'crestColor': 10278653,
#   'crestAssetId': 99150308},
#  {'clubId': 16046,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 13),
#   'name': 'A 4 7',
#   'regionId': 5064001,
#   'teamId': 166,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 1359875,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160620},
#  {'clubId': 13791,
#   'timestamp': datetime.datetime(2023, 11, 24, 3, 50, 23),
#   'name': 'M R G L H',
#   'regionId': 4281683,
#   'teamId': 115201,
#   'stadName': 'Emirates Stadium',
#   'kitId': 943726592,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 13179675,
#   'crestAssetId': 99160502},
#  {'clubId': 2018971,
#   'timestamp': datetime.datetime(2023, 11, 24, 3, 50, 23),
#   'name': 'T h u n d e r',
#   'regionId': 4281683,
#   'teamId': 11,
#   'stadName': 'Heinz von Heiden-Arena',
#   'kitId': 90113,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7852,
#   'customAwayKitId': 7514,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5004,
#   'kitColor1': 4920087,
#   'kitColor2': 14935011,
#   'kitColor3': 15921906,
#   'kitColor4': 15921906,
#   'kitAColor1': 592397,
#   'kitAColor2': 1841428,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 1987272,
#   'crestAssetId': 99160122},
#  {'clubId': 14086,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 43, 54),
#   'name': 'SOLDIERS',
#   'regionId': 5064001,
#   'teamId': 113300,
#   'stadName': 'Etihad Stadium',
#   'kitId': 928153601,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7600,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 8654629,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160816},
#  {'clubId': 16046,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 43, 54),
#   'name': 'A 4 7',
#   'regionId': 5064001,
#   'teamId': 166,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 1359875,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160620},
#  {'clubId': 3084976,
#   'timestamp': datetime.datetime(2023, 11, 22, 21, 13),
#   'name': 'Old Champions',
#   'regionId': 5064001,
#   'teamId': 18,
#   'stadName': 'Municipal de Ipurua',
#   'kitId': 147457,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160311},
#  {'clubId': 3692736,
#   'timestamp': datetime.datetime(2023, 11, 22, 20, 46, 57),
#   'name': 'Sons Of Badiah',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Badiah Stadium',
#   'kitId': 918642688,
#   'seasonalTeamId': 0,
#   'seasonalKitId': 0,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160122},
#  {'clubId': 2945406,
#   'timestamp': datetime.datetime(2023, 11, 22, 20, 2, 37),
#   'name': 'wesam club',
#   'regionId': 5064001,
#   'teamId': 9,
#   'stadName': 'Volkswagen Arena',
#   'kitId': 73728,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160728},
#  {'clubId': 13541,
#   'timestamp': datetime.datetime(2023, 11, 20, 19, 23, 57),
#   'name': 'S U P E R',
#   'regionId': 5064001,
#   'teamId': 111462,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 913096705,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7627,
#   'customAwayKitId': 7627,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 592397,
#   'kitColor2': 15921906,
#   'kitColor3': 15921906,
#   'kitColor4': 15921906,
#   'kitAColor1': 15921906,
#   'kitAColor2': 15245824,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15245824,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 1,
#   'crestColor': 0,
#   'crestAssetId': 99160115},
#  {'clubId': 2636601,
#   'timestamp': datetime.datetime(2023, 11, 20, 19, 23, 57),
#   'name': 's6awh',
#   'regionId': 5064001,
#   'teamId': 110374,
#   'stadName': 'Estadio José Zorrilla',
#   'kitId': 904183808,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404225,
#   'selectedKitType': 0,
#   'customKitId': 7510,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 16777215,
#   'crestAssetId': 99160421},
#  {'clubId': 798651,
#   'timestamp': datetime.datetime(2023, 11, 20, 19, 5, 20),
#   'name': 'One pieace 3mk',
#   'regionId': 5064001,
#   'teamId': 243,
#   'stadName': 'Power Horse Stadium',
#   'kitId': 1990656,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160720},
#  {'clubId': 824441,
#   'timestamp': datetime.datetime(2023, 11, 20, 18, 45, 15),
#   'name': 'Dark Academy',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Dark Stadium',
#   'kitId': 918642688,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7632,
#   'customAwayKitId': 7645,
#   'customThirdKitId': 7702,
#   'customKeeperKitId': 5028,
#   'kitColor1': 592397,
#   'kitColor2': 12525622,
#   'kitColor3': 11319490,
#   'kitColor4': 592397,
#   'kitAColor1': 10066329,
#   'kitAColor2': 15921906,
#   'kitAColor3': 6316643,
#   'kitAColor4': 6316643,
#   'kitThrdColor1': 1841428,
#   'kitThrdColor2': 15921906,
#   'kitThrdColor3': 5775459,
#   'kitThrdColor4': 5775459,
#   'dCustomKit': 0,
#   'crestColor': 1611589,
#   'crestAssetId': 99160608},
#  {'clubId': 877181,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 31, 6),
#   'name': 'Abuba Team',
#   'regionId': 5129557,
#   'teamId': 44,
#   'stadName': 'Abuba Arena',
#   'kitId': 360448,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160404},
#  {'clubId': 2613056,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 31, 6),
#   'name': 'Pin x Black',
#   'regionId': 4539733,
#   'teamId': 110953,
#   'stadName': 'BRASILIA',
#   'kitId': 908926977,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7517,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 13883203,
#   'kitColor2': 1256053,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99161121},
#  {'clubId': 2684656,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 7, 29),
#   'name': 'AC Fohlen LBC',
#   'regionId': 4539733,
#   'teamId': 1330,
#   'stadName': 'Düsseldorf-Arena',
#   'kitId': 10895360,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7648,
#   'customAwayKitId': 7600,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5007,
#   'kitColor1': 22436,
#   'kitColor2': 15921906,
#   'kitColor3': 15921906,
#   'kitColor4': 15921906,
#   'kitAColor1': 15921906,
#   'kitAColor2': 22436,
#   'kitAColor3': 22436,
#   'kitAColor4': 592397,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 1987272,
#   'crestAssetId': 99010413},
#  {'clubId': 2256236,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 39, 37),
#   'name': 'International',
#   'regionId': 4539733,
#   'teamId': 234,
#   'stadName': 'Tier 3 Stadium',
#   'kitId': 1916928,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160118},
#  {'clubId': 946091,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 16, 36),
#   'name': 'Friends  United',
#   'regionId': 4539733,
#   'teamId': 21,
#   'stadName': 'London Stadium',
#   'kitId': 172032,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7850,
#   'customAwayKitId': 7700,
#   'customThirdKitId': 7616,
#   'customKeeperKitId': 5014,
#   'kitColor1': 15101200,
#   'kitColor2': 592397,
#   'kitColor3': 15130831,
#   'kitColor4': 15921906,
#   'kitAColor1': 592397,
#   'kitAColor2': 14358546,
#   'kitAColor3': 16774144,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 14358546,
#   'kitThrdColor2': 15921906,
#   'kitThrdColor3': 1841428,
#   'kitThrdColor4': 1841428,
#   'dCustomKit': 0,
#   'crestColor': 0,
#   'crestAssetId': 99100101},
#  {'clubId': 1351871,
#   'timestamp': datetime.datetime(2023, 11, 23, 16, 54, 17),
#   'name': '1 BounceFC',
#   'regionId': 4344147,
#   'teamId': 45,
#   'stadName': 'Anfield',
#   'kitId': 368643,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7523,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 592397,
#   'kitColor2': 14935011,
#   'kitColor3': 14358546,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99161018},
#  {'clubId': 1109716,
#   'timestamp': datetime.datetime(2023, 11, 22, 7, 53, 51),
#   'name': 'alahlii fcc',
#   'regionId': 5064001,
#   'teamId': 605,
#   'stadName': 'Ibrox Stadium',
#   'kitId': 4956160,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160615},
#  {'clubId': 3830521,
#   'timestamp': datetime.datetime(2023, 11, 22, 7, 53, 51),
#   'name': 'M A S T E R S',
#   'regionId': 5064001,
#   'teamId': 605,
#   'stadName': 'Tier 1 Stadium',
#   'kitId': 4956160,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160722},
#  {'clubId': 439686,
#   'timestamp': datetime.datetime(2023, 11, 22, 7, 23, 36),
#   'name': 'KSA 10',
#   'regionId': 5064001,
#   'teamId': 112893,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 924819456,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7635,
#   'customAwayKitId': 7543,
#   'customThirdKitId': 7639,
#   'customKeeperKitId': 5006,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 15921906,
#   'kitColor4': 14358546,
#   'kitAColor1': 14358546,
#   'kitAColor2': 1336871,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 16774144,
#   'kitThrdColor2': 1336871,
#   'kitThrdColor3': 592397,
#   'kitThrdColor4': 592397,
#   'dCustomKit': 0,
#   'crestColor': 0,
#   'crestAssetId': 99160120},
#  {'clubId': 750036,
#   'timestamp': datetime.datetime(2023, 11, 22, 6, 56, 41),
#   'name': 'al taeawun',
#   'regionId': 5064001,
#   'teamId': 47,
#   'stadName': 'ملعب الدرجة 2',
#   'kitId': 385024,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7632,
#   'customAwayKitId': 7572,
#   'customThirdKitId': 7647,
#   'customKeeperKitId': 5000,
#   'kitColor1': 33627,
#   'kitColor2': 15921906,
#   'kitColor3': 22436,
#   'kitColor4': 15921906,
#   'kitAColor1': 15921906,
#   'kitAColor2': 22436,
#   'kitAColor3': 22436,
#   'kitAColor4': 22436,
#   'kitThrdColor1': 592397,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 15921906,
#   'kitThrdColor4': 15921906,
#   'dCustomKit': 0,
#   'crestColor': 1611589,
#   'crestAssetId': 99150607},
#  {'clubId': 1869141,
#   'timestamp': datetime.datetime(2023, 11, 22, 6, 35, 33),
#   'name': 'NADE AL O6N',
#   'regionId': 5064001,
#   'teamId': 607,
#   'stadName': 'Estádio do Dragão',
#   'kitId': 4972544,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7703,
#   'customThirdKitId': 7601,
#   'customKeeperKitId': 5010,
#   'kitColor1': 1336871,
#   'kitColor2': 15921906,
#   'kitColor3': 15921906,
#   'kitColor4': 592397,
#   'kitAColor1': 15921906,
#   'kitAColor2': 1336871,
#   'kitAColor3': 1336871,
#   'kitAColor4': 592397,
#   'kitThrdColor1': 592397,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 15921906,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 1,
#   'crestColor': 1611589,
#   'crestAssetId': 99090604},
#  {'clubId': 14086,
#   'timestamp': datetime.datetime(2023, 11, 21, 23, 56, 2),
#   'name': 'SOLDIERS',
#   'regionId': 5064001,
#   'teamId': 113300,
#   'stadName': 'Etihad Stadium',
#   'kitId': 928153601,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7600,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 8654629,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160816},
#  {'clubId': 2187911,
#   'timestamp': datetime.datetime(2023, 11, 13, 14, 18, 20),
#   'name': 'Anan Damatenmag',
#   'regionId': 4539733,
#   'teamId': 1825,
#   'stadName': 'SchücoArena',
#   'kitId': 14950400,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7530,
#   'customAwayKitId': 7513,
#   'customThirdKitId': 7543,
#   'customKeeperKitId': 5011,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 14277081,
#   'kitAColor1': 4133724,
#   'kitAColor2': 22436,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 8654629,
#   'kitThrdColor2': 15921906,
#   'kitThrdColor3': 592397,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 3,
#   'crestColor': 0,
#   'crestAssetId': 99160122},
#  {'clubId': 3302026,
#   'timestamp': datetime.datetime(2023, 11, 13, 14, 18, 20),
#   'name': 'Smøkin Aces',
#   'regionId': 4344147,
#   'teamId': 112134,
#   'stadName': 'The Aces Arena',
#   'kitId': 918601729,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160127},
#  {'clubId': 462826,
#   'timestamp': datetime.datetime(2023, 11, 13, 14, 6, 43),
#   'name': 'D K 24',
#   'regionId': 5457237,
#   'teamId': 10,
#   'stadName': 'Loftus Road',
#   'kitId': 81923,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7534,
#   'customAwayKitId': 7600,
#   'customThirdKitId': 7704,
#   'customKeeperKitId': 5005,
#   'kitColor1': 14358546,
#   'kitColor2': 16774144,
#   'kitColor3': 592397,
#   'kitColor4': 15921906,
#   'kitAColor1': 592397,
#   'kitAColor2': 858211,
#   'kitAColor3': 14358546,
#   'kitAColor4': 14358546,
#   'kitThrdColor1': 15921906,
#   'kitThrdColor2': 2164288,
#   'kitThrdColor3': 15101200,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 3,
#   'crestColor': 1611589,
#   'crestAssetId': 99160605},
#  {'clubId': 1755291,
#   'timestamp': datetime.datetime(2023, 11, 12, 15, 54, 51),
#   'name': 'Lidl Plus',
#   'regionId': 4539733,
#   'teamId': 243,
#   'stadName': 'Emirates Stadium',
#   'kitId': 1990656,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7536,
#   'customAwayKitId': 7525,
#   'customThirdKitId': 7704,
#   'customKeeperKitId': 5025,
#   'kitColor1': 1841428,
#   'kitColor2': 11670838,
#   'kitColor3': 592397,
#   'kitColor4': 15921906,
#   'kitAColor1': 15921906,
#   'kitAColor2': 592397,
#   'kitAColor3': 11670838,
#   'kitAColor4': 592397,
#   'kitThrdColor1': 1841428,
#   'kitThrdColor2': 592397,
#   'kitThrdColor3': 15921906,
#   'kitThrdColor4': 15921906,
#   'dCustomKit': 0,
#   'crestColor': 13179675,
#   'crestAssetId': 99160522},
#  {'clubId': 2793741,
#   'timestamp': datetime.datetime(2023, 11, 12, 15, 38, 27),
#   'name': 'Sheep Army',
#   'regionId': 4344147,
#   'teamId': 1961,
#   'stadName': 'Estadio José Zorrilla',
#   'kitId': 16064512,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7665,
#   'customAwayKitId': 7526,
#   'customThirdKitId': 7668,
#   'customKeeperKitId': 5026,
#   'kitColor1': 13979995,
#   'kitColor2': 2704542,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 2704542,
#   'kitAColor3': 15101200,
#   'kitAColor4': 16774144,
#   'kitThrdColor1': 16464712,
#   'kitThrdColor2': 16774144,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 1987272,
#   'crestAssetId': 99160425},
#  {'clubId': 1775926,
#   'timestamp': datetime.datetime(2023, 11, 12, 15, 31, 56),
#   'name': 'tropical airpod',
#   'regionId': 4344147,
#   'teamId': 2,
#   'stadName': 'BC Place',
#   'kitId': 16384,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7644,
#   'customAwayKitId': 7517,
#   'customThirdKitId': 7703,
#   'customKeeperKitId': 5025,
#   'kitColor1': 15921906,
#   'kitColor2': 10066329,
#   'kitColor3': 6316643,
#   'kitColor4': 10066329,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 592397,
#   'kitThrdColor2': 14358546,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 14358546,
#   'dCustomKit': 0,
#   'crestColor': 0,
#   'crestAssetId': 99110101},
#  {'clubId': 241951,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 19, 37),
#   'name': 'Glacia FC',
#   'regionId': 4539733,
#   'teamId': 243,
#   'stadName': 'ATATURK STADYUM',
#   'kitId': 1990656,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160722},
#  {'clubId': 2256236,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 19, 37),
#   'name': 'International',
#   'regionId': 4539733,
#   'teamId': 234,
#   'stadName': 'Tier 3 Stadium',
#   'kitId': 1916928,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160118},
#  {'clubId': 2684656,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 1, 2),
#   'name': 'AC Fohlen LBC',
#   'regionId': 4539733,
#   'teamId': 1330,
#   'stadName': 'Düsseldorf-Arena',
#   'kitId': 10895360,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7648,
#   'customAwayKitId': 7600,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5007,
#   'kitColor1': 22436,
#   'kitColor2': 15921906,
#   'kitColor3': 15921906,
#   'kitColor4': 15921906,
#   'kitAColor1': 15921906,
#   'kitAColor2': 22436,
#   'kitAColor3': 22436,
#   'kitAColor4': 592397,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 1987272,
#   'crestAssetId': 99010413},
#  {'clubId': 2613056,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 39, 37),
#   'name': 'Pin x Black',
#   'regionId': 4539733,
#   'teamId': 110953,
#   'stadName': 'BRASILIA',
#   'kitId': 908926977,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7517,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 13883203,
#   'kitColor2': 1256053,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99161121},
#  {'clubId': 2118651,
#   'timestamp': datetime.datetime(2023, 11, 23, 16, 59, 48),
#   'name': 'pompoms',
#   'regionId': 5129557,
#   'teamId': 1,
#   'stadName': 'El Alcoraz',
#   'kitId': 8192,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7641,
#   'customAwayKitId': 7522,
#   'customThirdKitId': 7636,
#   'customKeeperKitId': 5032,
#   'kitColor1': 16464712,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 7122142,
#   'kitAColor2': 1259409,
#   'kitAColor3': 16774144,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 15245824,
#   'kitThrdColor2': 16696614,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160718},
#  {'clubId': 17186,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 10, 10),
#   'name': 'S K Y',
#   'regionId': 5064001,
#   'teamId': 1335,
#   'stadName': 'Tier 3 Stadium',
#   'kitId': 10936320,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7629,
#   'customAwayKitId': 7704,
#   'customThirdKitId': 7551,
#   'customKeeperKitId': 5032,
#   'kitColor1': 13979995,
#   'kitColor2': 11319490,
#   'kitColor3': 592397,
#   'kitColor4': 11319490,
#   'kitAColor1': 14655653,
#   'kitAColor2': 1841428,
#   'kitAColor3': 592397,
#   'kitAColor4': 1841428,
#   'kitThrdColor1': 12762028,
#   'kitThrdColor2': 592397,
#   'kitThrdColor3': 15921906,
#   'kitThrdColor4': 15921906,
#   'dCustomKit': 0,
#   'crestColor': 13179675,
#   'crestAssetId': 99130501},
#  {'clubId': 1567011,
#   'timestamp': datetime.datetime(2023, 11, 23, 18, 10, 10),
#   'name': '3mblos',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Estadio Ciutat de València',
#   'kitId': 918642688,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 9127890,
#   'crestAssetId': 99161027},
#  {'clubId': 709021,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 41, 43),
#   'name': 'Royall FC',
#   'regionId': 5064001,
#   'teamId': 112387,
#   'stadName': 'Estadio José Zorrilla',
#   'kitId': 920674304,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7851,
#   'customAwayKitId': 7540,
#   'customThirdKitId': 7603,
#   'customKeeperKitId': 5025,
#   'kitColor1': 592397,
#   'kitColor2': 5775459,
#   'kitColor3': 5775459,
#   'kitColor4': 592397,
#   'kitAColor1': 16045584,
#   'kitAColor2': 15921906,
#   'kitAColor3': 592397,
#   'kitAColor4': 592397,
#   'kitThrdColor1': 1713203,
#   'kitThrdColor2': 1909296,
#   'kitThrdColor3': 13979995,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': 9127890,
#   'crestAssetId': 99160919},
#  {'clubId': 438366,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 20, 18),
#   'name': 'ggaagg',
#   'regionId': 5064001,
#   'teamId': 73,
#   'stadName': 'Mercedes-Benz Stadium',
#   'kitId': 598016,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 1,
#   'customKitId': 7509,
#   'customAwayKitId': 7539,
#   'customThirdKitId': 7630,
#   'customKeeperKitId': 5032,
#   'kitColor1': 1841428,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 16464712,
#   'kitAColor3': 16696614,
#   'kitAColor4': 7192366,
#   'kitThrdColor1': 15921906,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 2510903,
#   'kitThrdColor4': 1482375,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160616},
#  {'clubId': 15811,
#   'timestamp': datetime.datetime(2023, 11, 23, 17, 0, 11),
#   'name': 'Saudi',
#   'regionId': 5064001,
#   'teamId': 607,
#   'stadName': 'Ibrox Stadium',
#   'kitId': 4972544,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7702,
#   'customAwayKitId': 7601,
#   'customThirdKitId': 7543,
#   'customKeeperKitId': 5005,
#   'kitColor1': 592397,
#   'kitColor2': 15921906,
#   'kitColor3': 4133724,
#   'kitColor4': 8654629,
#   'kitAColor1': 15921906,
#   'kitAColor2': 2164288,
#   'kitAColor3': 8654629,
#   'kitAColor4': 1909296,
#   'kitThrdColor1': 4920087,
#   'kitThrdColor2': 15921906,
#   'kitThrdColor3': 5775459,
#   'kitThrdColor4': 8654629,
#   'dCustomKit': 0,
#   'crestColor': 9127890,
#   'crestAssetId': 99160910},
#  {'clubId': 729116,
#   'timestamp': datetime.datetime(2023, 11, 23, 16, 50, 13),
#   'name': 'FC P o r t o',
#   'regionId': 5064001,
#   'teamId': 131389,
#   'stadName': 'Anfield',
#   'kitId': 1076338689,
#   'seasonalTeamId': 131398,
#   'seasonalKitId': 1076412416,
#   'selectedKitType': 0,
#   'customKitId': 7702,
#   'customAwayKitId': 7700,
#   'customThirdKitId': 7643,
#   'customKeeperKitId': 5009,
#   'kitColor1': 11319490,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 33627,
#   'kitAColor2': 13883203,
#   'kitAColor3': 1256053,
#   'kitAColor4': 3427409,
#   'kitThrdColor1': 14358546,
#   'kitThrdColor2': 1841428,
#   'kitThrdColor3': 14935011,
#   'kitThrdColor4': 15921906,
#   'dCustomKit': 3,
#   'crestColor': 16777215,
#   'crestAssetId': 99110204},
#  {'clubId': 662486,
#   'timestamp': datetime.datetime(2023, 11, 23, 6, 5, 26),
#   'name': 'S  P  U  R  S',
#   'regionId': 5064001,
#   'teamId': 65,
#   'stadName': 'Estadio San Mamés',
#   'kitId': 532483,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160625},
#  {'clubId': 2900086,
#   'timestamp': datetime.datetime(2023, 11, 23, 6, 5, 26),
#   'name': 'Tyaar',
#   'regionId': 5064001,
#   'teamId': 241,
#   'stadName': 'Estadio José Zorrilla',
#   'kitId': 1974272,
#   'seasonalTeamId': 0,
#   'seasonalKitId': 0,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160626},
#  {'clubId': 764421,
#   'timestamp': datetime.datetime(2023, 11, 23, 5, 44, 55),
#   'name': '5Ieha 3I allh',
#   'regionId': 5064001,
#   'teamId': 243,
#   'stadName': 'El Alcoraz',
#   'kitId': 1990656,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160115},
#  {'clubId': 4152706,
#   'timestamp': datetime.datetime(2023, 11, 23, 5, 34, 11),
#   'name': 'Gharafa FC',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Tier 1 Stadium',
#   'kitId': 918642688,
#   'customKitId': 7509,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'customAwayKitId': 7509,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'customThirdKitId': 7511,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'customKeeperKitId': 5005,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160327,
#   'seasonalTeamId': 0,
#   'seasonalKitId': 0,
#   'selectedKitType': 0}]

# %%
json_dict
# Out:
# [{'matchId': '24932216390150',
#   'timestamp': 1700737526,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700737524',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '2',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '2900086': {'date': '1700737524',
#     'gameNumber': '0',
#     'goals': '2',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '2',
#     'season_id': '0',
#     'TEAM': '241',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Tyaar',
#      'clubId': 2900086,
#      'regionId': 5064001,
#      'teamId': 241,
#      'customKit': {'stadName': 'Estadio José Zorrilla',
#       'kitId': '1974272',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160626'}}}},
#   'players': {'2900086': {'1281893699': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '22',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '7.20',
#      'realtimegame': '949',
#      'realtimeidle': '7',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '0',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': '096|095|088|089|067|077|059|085|062|085|064|089|076|091|079|089|076|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'iLord_92'},
#     '1734355884': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '75',
#      'passesmade': '70',
#      'pos': '',
#      'rating': '6.40',
#      'realtimegame': '3533',
#      'realtimeidle': '9',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '8',
#      'tackleattempts': '36',
#      'tacklesmade': '10',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'iDvLz-121'},
#     '1984307914': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '26',
#      'passesmade': '19',
#      'pos': 'midfielder',
#      'rating': '8.10',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '3',
#      'tackleattempts': '4',
#      'tacklesmade': '1',
#      'vproattr': '093|088|087|085|069|072|058|085|062|083|064|087|093|093|093|089|075|079|063|091|096|065|067|077|067|065|073|098|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'Mo7ssan'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '6.90',
#      'realtimegame': '949',
#      'realtimeidle': '78',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '19',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '8.00',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '15',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '7.00',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '10',
#      'tacklesmade': '2',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '7',
#      'passesmade': '6',
#      'pos': 'forward',
#      'rating': '8.60',
#      'realtimegame': '949',
#      'realtimeidle': '128',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '9',
#      'passesmade': '8',
#      'pos': 'midfielder',
#      'rating': '6.40',
#      'realtimegame': '949',
#      'realtimeidle': '8',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '16',
#      'tacklesmade': '3',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '45',
#      'passesmade': '43',
#      'pos': '',
#      'rating': '7.10',
#      'realtimegame': '949',
#      'realtimeidle': '8',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '4',
#      'tackleattempts': '25',
#      'tacklesmade': '7',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'2900086': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 2,
#     'goalsconceded': 12,
#     'losses': 3,
#     'mom': 0,
#     'namespace': 3,
#     'passattempts': 123,
#     'passesmade': 109,
#     'pos': 0,
#     'rating': 21.7,
#     'realtimegame': 5431,
#     'realtimeidle': 26,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 6,
#     'shots': 11,
#     'tackleattempts': 43,
#     'tacklesmade': 12,
#     'vproattr': 0,
#     'vprohackreason': 16,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 12,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 107,
#     'passesmade': 93,
#     'pos': 0,
#     'rating': 44.0,
#     'realtimegame': 5694,
#     'realtimeidle': 242,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 24,
#     'shots': 6,
#     'tackleattempts': 55,
#     'tacklesmade': 13,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24920264080311',
#   'timestamp': 1700736295,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700736294',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '764421': {'date': '1700736294',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '243',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': '5Ieha 3I allh',
#      'clubId': 764421,
#      'regionId': 5064001,
#      'teamId': 243,
#      'customKit': {'stadName': 'El Alcoraz',
#       'kitId': '1990656',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160115'}}}},
#   'players': {'764421': {'1111325960': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '6',
#      'passesmade': '4',
#      'pos': 'midfielder',
#      'rating': '5.70',
#      'realtimegame': '556',
#      'realtimeidle': '17',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '1',
#      'tackleattempts': '4',
#      'tacklesmade': '1',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'sq_Yi'},
#     '1845197370': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'goalkeeper',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'kq--77'},
#     '1871269370': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Toflk-'},
#     '1930904856': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '7.60',
#      'realtimegame': '7489',
#      'realtimeidle': '33',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '078|080|089|091|070|071|059|085|063|083|064|088|093|096|091|087|081|079|064|091|091|066|072|077|068|066|073|089|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'shybmar876-shybm'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '9',
#      'passesmade': '7',
#      'pos': 'midfielder',
#      'rating': '6.40',
#      'realtimegame': '555',
#      'realtimeidle': '18',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '3',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '9.20',
#      'realtimegame': '555',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '7.30',
#      'realtimegame': '555',
#      'realtimeidle': '11',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '8',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '10',
#      'passesmade': '8',
#      'pos': 'forward',
#      'rating': '9.10',
#      'realtimegame': '555',
#      'realtimeidle': '75',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '5',
#      'pos': 'midfielder',
#      'rating': '6.20',
#      'realtimegame': '555',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '12',
#      'tacklesmade': '0',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '34',
#      'passesmade': '32',
#      'pos': '',
#      'rating': '6.90',
#      'realtimegame': '555',
#      'realtimeidle': '4',
#      'redcards': '0',
#      'saves': '1',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '11',
#      'tacklesmade': '3',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'764421': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 4,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 4,
#     'passattempts': 6,
#     'passesmade': 4,
#     'pos': 0,
#     'rating': 19.3,
#     'realtimegame': 8045,
#     'realtimeidle': 50,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 4,
#     'shots': 1,
#     'tackleattempts': 4,
#     'tacklesmade': 1,
#     'vproattr': 0,
#     'vprohackreason': 8,
#     'wins': 0},
#    '662486': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 87,
#     'passesmade': 73,
#     'pos': 0,
#     'rating': 45.1,
#     'realtimegame': 3330,
#     'realtimeidle': 124,
#     'redcards': 0,
#     'saves': 1,
#     'SCORE': 24,
#     'shots': 4,
#     'tackleattempts': 36,
#     'tacklesmade': 6,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24932193940123',
#   'timestamp': 1700735651,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700735649',
#     'gameNumber': '0',
#     'goals': '3',
#     'goalsAgainst': '0',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '3',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700735649',
#     'gameNumber': '0',
#     'goals': '0',
#     'goalsAgainst': '3',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '0',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.60',
#      'realtimegame': '77002',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.80',
#      'realtimegame': '255',
#      'realtimeidle': '14',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1007324980209': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '3',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '3',
#      'passesmade': '3',
#      'pos': 'midfielder',
#      'rating': '5.80',
#      'realtimegame': '23230',
#      'realtimeidle': '49',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'abo5ly-_-'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.70',
#      'realtimegame': '275',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '6.90',
#      'realtimegame': '275',
#      'realtimeidle': '37',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '3',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '7',
#      'passesmade': '5',
#      'pos': 'midfielder',
#      'rating': '9.30',
#      'realtimegame': '275',
#      'realtimeidle': '5',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '2',
#      'passesmade': '2',
#      'pos': 'midfielder',
#      'rating': '6.30',
#      'realtimegame': '275',
#      'realtimeidle': '3',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '0',
#      'tackleattempts': '3',
#      'tacklesmade': '0',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '4',
#      'passesmade': '4',
#      'pos': 'forward',
#      'rating': '7.70',
#      'realtimegame': '275',
#      'realtimeidle': '24',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '4',
#      'passesmade': '2',
#      'pos': 'midfielder',
#      'rating': '6.50',
#      'realtimegame': '275',
#      'realtimeidle': '1',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '2',
#      'tacklesmade': '1',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '1',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '6',
#      'pos': '',
#      'rating': '6.10',
#      'realtimegame': '275',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '3',
#      'tackleattempts': '11',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 3,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 4,
#     'passattempts': 3,
#     'passesmade': 3,
#     'pos': 0,
#     'rating': 22.9,
#     'realtimegame': 100762,
#     'realtimeidle': 79,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 4,
#     'shots': 0,
#     'tackleattempts': 0,
#     'tacklesmade': 0,
#     'vproattr': 0,
#     'vprohackreason': 32,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 1,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 3,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 25,
#     'passesmade': 19,
#     'pos': 0,
#     'rating': 42.8,
#     'realtimegame': 1650,
#     'realtimeidle': 70,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 18,
#     'shots': 6,
#     'tackleattempts': 17,
#     'tacklesmade': 2,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24906309550476',
#   'timestamp': 1700735201,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700735200',
#     'gameNumber': '0',
#     'goals': '5',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '5',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700735200',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '5',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.30',
#      'realtimegame': '76378',
#      'realtimeidle': '42',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '7.80',
#      'realtimegame': '855',
#      'realtimeidle': '51',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1003778529393': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'OhhRuthless--'},
#     '1007324980209': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'forward',
#      'rating': '6.00',
#      'realtimegame': '22765',
#      'realtimeidle': '34',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'abo5ly-_-'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '5',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '11',
#      'passesmade': '9',
#      'pos': 'forward',
#      'rating': '5.90',
#      'realtimegame': '938',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '1',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '7',
#      'pos': 'midfielder',
#      'rating': '7.50',
#      'realtimegame': '938',
#      'realtimeidle': '55',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '4',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '5',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '25',
#      'passesmade': '19',
#      'pos': 'midfielder',
#      'rating': '10.00',
#      'realtimegame': '938',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '7.40',
#      'realtimegame': '938',
#      'realtimeidle': '35',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '12',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '916',
#      'realtimeidle': '176',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '7.90',
#      'realtimegame': '938',
#      'realtimeidle': '25',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '1',
#      'tackleattempts': '24',
#      'tacklesmade': '5',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '39',
#      'passesmade': '34',
#      'pos': '',
#      'rating': '7.00',
#      'realtimegame': '938',
#      'realtimeidle': '23',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '6',
#      'tackleattempts': '19',
#      'tacklesmade': '7',
#      'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 5,
#     'losses': 5,
#     'mom': 0,
#     'namespace': 5,
#     'passattempts': 11,
#     'passesmade': 9,
#     'pos': 0,
#     'rating': 28.0,
#     'realtimegame': 100936,
#     'realtimeidle': 146,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 5,
#     'shots': 1,
#     'tackleattempts': 1,
#     'tacklesmade': 0,
#     'vproattr': 0,
#     'vprohackreason': 32,
#     'wins': 0},
#    '662486': {'assists': 5,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 3,
#     'goalsconceded': 5,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 98,
#     'passesmade': 81,
#     'pos': 0,
#     'rating': 48.8,
#     'realtimegame': 5606,
#     'realtimeidle': 333,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 30,
#     'shots': 11,
#     'tackleattempts': 55,
#     'tacklesmade': 13,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24932154470015',
#   'timestamp': 1700734033,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700734031',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700734031',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '76',
#      'passesmade': '70',
#      'pos': '',
#      'rating': '6.00',
#      'realtimegame': '962',
#      'realtimeidle': '29',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '3',
#      'tackleattempts': '40',
#      'tacklesmade': '1',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '15',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '7.90',
#      'realtimegame': '962',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '7',
#      'tacklesmade': '4',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1003778529393': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': '',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'OhhRuthless--'},
#     '1005482916657': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': '',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'mujahid_m99'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '11',
#      'pos': 'forward',
#      'rating': '6.20',
#      'realtimegame': '962',
#      'realtimeidle': '35',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '5',
#      'passesmade': '4',
#      'pos': 'midfielder',
#      'rating': '6.20',
#      'realtimegame': '962',
#      'realtimeidle': '42',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '25',
#      'passesmade': '22',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '962',
#      'realtimeidle': '12',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '2',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '22',
#      'passesmade': '15',
#      'pos': 'midfielder',
#      'rating': '8.60',
#      'realtimegame': '962',
#      'realtimeidle': '14',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '13',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '13',
#      'pos': 'forward',
#      'rating': '8.00',
#      'realtimegame': '2552',
#      'realtimeidle': '101',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '17',
#      'passesmade': '15',
#      'pos': 'midfielder',
#      'rating': '8.00',
#      'realtimegame': '962',
#      'realtimeidle': '13',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '19',
#      'tacklesmade': '7',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '3',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '34',
#      'passesmade': '33',
#      'pos': '',
#      'rating': '7.10',
#      'realtimegame': '2242',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '10',
#      'tackleattempts': '23',
#      'tacklesmade': '5',
#      'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 1,
#     'goalsconceded': 12,
#     'losses': 5,
#     'mom': 0,
#     'namespace': 5,
#     'passattempts': 105,
#     'passesmade': 91,
#     'pos': 0,
#     'rating': 26.1,
#     'realtimegame': 2886,
#     'realtimeidle': 70,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 5,
#     'shots': 3,
#     'tackleattempts': 47,
#     'tacklesmade': 5,
#     'vproattr': 0,
#     'vprohackreason': 24,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 117,
#     'passesmade': 102,
#     'pos': 0,
#     'rating': 46.9,
#     'realtimegame': 8642,
#     'realtimeidle': 191,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 24,
#     'shots': 15,
#     'tackleattempts': 58,
#     'tacklesmade': 14,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}}]

# %%
match_overview_dictionary_list
match_overview_dictionary_df = pd.DataFrame(match_overview_dictionary_list)
match_overview_dictionary_df
# Out:
#            matchId                timestamp team_1_date team_1_gameNumber  \
# 0   25182250910116  2023-11-24 06:15:10 UTC  1700806508                 0
# 1   25156461070308  2023-11-24 05:42:39 UTC  1700804558                 0
# 2   24860304270416  2023-11-23 02:51:42 UTC  1700707900                 0
# 3   24812847840410  2023-11-23 02:31:48 UTC  1700706706                 0
# 4   24824602830453  2023-11-23 02:13:00 UTC  1700705578                 0
# 5   25200092700465  2023-11-24 08:50:23 UTC  1700815822                 0
# 6   25196195260448  2023-11-24 08:47:13 UTC  1700815632                 0
# 7   25160614240017  2023-11-24 08:44:08 UTC  1700815447                 0
# 8   25162567920196  2023-11-24 08:40:58 UTC  1700815257                 0
# 9   25198115370336  2023-11-24 08:37:32 UTC  1700815052                 0
# 10  24850516930359  2023-11-23 02:43:54 UTC  1700707432                 0
# 11  24824602830453  2023-11-23 02:13:00 UTC  1700705578                 0
# 12  24834487800370  2023-11-23 01:46:57 UTC  1700704016                 0
# 13  24816579750407  2023-11-23 01:22:41 UTC  1700702559                 0
# 14  24846305170373  2023-11-23 01:02:37 UTC  1700701356                 0
# 15  24238572590478  2023-11-21 00:23:57 UTC  1700526236                 0
# 16  24238543160221  2023-11-21 00:05:20 UTC  1700525119                 0
# 17  24228657490408  2023-11-20 23:53:42 UTC  1700524421                 0
# 18  24258390260500  2023-11-20 23:45:15 UTC  1700523914                 0
# 19  24258347750203  2023-11-20 23:36:39 UTC  1700523398                 0
# 20  25074529550070  2023-11-23 23:31:06 UTC  1700782265                 0
# 21  25092363060197  2023-11-23 23:07:29 UTC  1700780848                 0
# 22  25056553030241  2023-11-23 22:39:37 UTC  1700779175                 0
# 23  25054520650158  2023-11-23 22:16:36 UTC  1700777794                 0
# 24  25058392830477  2023-11-23 21:54:17 UTC  1700776456                 0
# 25  24584877570269  2023-11-22 12:53:51 UTC  1700657629                 0
# 26  24624104790242  2023-11-22 12:23:36 UTC  1700655815                 0
# 27  24610591110162  2023-11-22 11:56:41 UTC  1700654200                 0
# 28  24576860970293  2023-11-22 11:35:33 UTC  1700652932                 0
# 29  24614042950388  2023-11-22 04:56:02 UTC  1700628960                 0
# 30  21926544350236  2023-11-13 19:18:20 UTC  1699903099                 0
# 31  21948316230461  2023-11-13 19:06:43 UTC  1699902402                 0
# 32  21674914580417  2023-11-12 20:54:51 UTC  1699822490                 0
# 33  21680779480027  2023-11-12 20:38:27 UTC  1699821506                 0
# 34  21674812670041  2023-11-12 20:31:56 UTC  1699821115                 0
# 35  25090356510180  2023-11-23 23:19:37 UTC  1700781576                 0
# 36  25096277520132  2023-11-23 23:01:02 UTC  1700780461                 0
# 37  25056553030241  2023-11-23 22:39:37 UTC  1700779175                 0
# 38  25086126620045  2023-11-23 22:19:22 UTC  1700777960                 0
# 39  25086039030128  2023-11-23 21:59:48 UTC  1700776786                 0
# 40  25060613570286  2023-11-23 23:10:10 UTC  1700781009                 0
# 41  25092200660407  2023-11-23 22:41:43 UTC  1700779301                 0
# 42  25088168560243  2023-11-23 22:20:18 UTC  1700778017                 0
# 43  25084118240181  2023-11-23 22:00:11 UTC  1700776810                 0
# 44  25040805740234  2023-11-23 21:50:13 UTC  1700776211                 0
# 45  24932216390150  2023-11-23 11:05:26 UTC  1700737524                 0
# 46  24920264080311  2023-11-23 10:44:55 UTC  1700736294                 0
# 47  24932193940123  2023-11-23 10:34:11 UTC  1700735649                 0
# 48  24906309550476  2023-11-23 10:26:41 UTC  1700735200                 0
# 49  24932154470015  2023-11-23 10:07:13 UTC  1700734031                 0
#
#    team_1_goals team_1_goalsAgainst team_1_losses team_1_matchType  \
# 0             0                   2             1                1
# 1             2                   5             1                1
# 2             2                   6             1                1
# 3             3                   1             0                1
# 4             3                   3             0                1
# 5             3                   0             0                1
# 6             3                   0             0                1
# 7             3                   0             0                1
# 8             3                   0             0                1
# 9             3                   0             0                1
# 10            1                   4             1                1
# 11            3                   3             0                1
# 12            4                   0             0                1
# 13            1                   4             1                1
# 14            6                   1             0                1
# 15            9                   3             0                1
# 16            6                   1             0                1
# 17            6                   2             0                1
# 18            5                   2             0                1
# 19            5                   1             0                1
# 20            4                   4             0                1
# 21            3                   0             0                1
# 22            4                   1             0                1
# 23            1                   6             1                1
# 24            0                   3             1                1
# 25            3                   7             1                1
# 26            0                   4             1                1
# 27            0                   4             1                1
# 28            0                   4             1                1
# 29            2                   4             1                1
# 30            0                   4             1                1
# 31            0                   5             1                1
# 32            1                   3             1                1
# 33            0                   4             1                1
# 34            0                   9             1                1
# 35            2                   6             1                1
# 36            4                   1             0                1
# 37            4                   1             0                1
# 38            0                   2             1                1
# 39            0                   4             1                1
# 40            6                   2             0                1
# 41            4                   2             0                1
# 42            3                   0             0                1
# 43            0                   5             1                1
# 44            2                   5             1                1
# 45            4                   2             0                1
# 46            4                   1             0                1
# 47            3                   0             0                1
# 48            5                   1             0                1
# 49            4                   1             0                1
#
#    team_1_result team_1_score  ... team_2_season_id team_2_TEAM team_2_ties  \
# 0              2            0  ...                0          18           0
# 1              2            2  ...                0          18           0
# 2              2            2  ...                0        1335           0
# 3              1            3  ...                0      112139           0
# 4              4            3  ...                0        1335           1
# 5          16385            3  ...                0          11           0
# 6          16385            3  ...                0          11           0
# 7          16385            3  ...                0          11           0
# 8          16385            3  ...                0          11           0
# 9          16385            3  ...                0          11           0
# 10             2            1  ...                0      116428           0
# 11             4            3  ...                0        1335           1
# 12         16385            4  ...                0      112139           0
# 13             2            1  ...                0        1335           0
# 14         16385            6  ...                0      112387           0
# 15             1            9  ...                0          10           0
# 16         16385            6  ...                0         243           0
# 17         16385            6  ...                0         243           0
# 18         16385            5  ...                0    99160608           0
# 19         16385            5  ...                0    99160608           0
# 20             4            4  ...                0      110953           1
# 21         16385            3  ...                0    99010413           0
# 22             1            4  ...                0      110953           0
# 23             2            1  ...                0      110953           0
# 24            10            0  ...                0      110953           0
# 25             2            3  ...                0         605           0
# 26             2            0  ...                0         605           0
# 27            10            0  ...                0         605           0
# 28            10            0  ...                0         605           0
# 29             2            2  ...                0         605           0
# 30            10            0  ...                0      112134           0
# 31            10            0  ...                0      112134           0
# 32             2            1  ...                0      112134           0
# 33            10            0  ...                0      112134           0
# 34            10            0  ...                0      112134           0
# 35             2            2  ...                0         234           0
# 36         16385            4  ...                0    99010413           0
# 37             1            4  ...                0      110953           0
# 38             2            0  ...                0         234           0
# 39             2            0  ...                0         234           0
# 40             1            6  ...                0      112139           0
# 41             1            4  ...                0      112387           0
# 42         16385            3  ...                0    99160616           0
# 43            10            0  ...                0        1335           0
# 44             2            2  ...                0         327           0
# 45             1            4  ...                0         241           0
# 46         16385            4  ...                0         243           0
# 47         16385            3  ...                0      112139           0
# 48         16385            5  ...                0      112139           0
# 49             1            4  ...                0      112139           0
#
#    team_2_winnerByDnf team_2_wins team_2_details_name team_2_details_clubId  \
# 0                   0           1       Old Champions               3084976
# 1                   0           1       Old Champions               3084976
# 2                   0           1       Old Champions               3084976
# 3                   0           0            Coldplay               4071716
# 4                   0           0       Old Champions               3084976
# 5                   0           0       T h u n d e r               2018971
# 6                   0           0       T h u n d e r               2018971
# 7                   0           0       T h u n d e r               2018971
# 8                   0           0       T h u n d e r               2018971
# 9                   0           0       T h u n d e r               2018971
# 10                  0           1               A 4 7                 16046
# 11                  0           0       Old Champions               3084976
# 12                  0           0      Sons Of Badiah               3692736
# 13                  0           1       Old Champions               3084976
# 14                  0           0          wesam club               2945406
# 15                  0           0               s6awh               2636601
# 16                  0           0      One pieace 3mk                798651
# 17                  0           0      One pieace 3mk                798651
# 18                  0           0        Dark Academy                824441
# 19                  0           0        Dark Academy                824441
# 20                  0           0         Pin x Black               2613056
# 21                  0           0       AC Fohlen LBC               2684656
# 22                  0           0         Pin x Black               2613056
# 23                  0           1         Pin x Black               2613056
# 24                  1           1         Pin x Black               2613056
# 25                  0           1       M A S T E R S               3830521
# 26                  0           1       M A S T E R S               3830521
# 27                  1           1       M A S T E R S               3830521
# 28                  1           1       M A S T E R S               3830521
# 29                  0           1       M A S T E R S               3830521
# 30                  1           1         Smøkin Aces               3302026
# 31                  1           1         Smøkin Aces               3302026
# 32                  0           1         Smøkin Aces               3302026
# 33                  1           1         Smøkin Aces               3302026
# 34                  1           1         Smøkin Aces               3302026
# 35                  0           1       International               2256236
# 36                  0           0       AC Fohlen LBC               2684656
# 37                  0           0         Pin x Black               2613056
# 38                  0           1       International               2256236
# 39                  0           1       International               2256236
# 40                  0           0              3mblos               1567011
# 41                  0           0           Royall FC                709021
# 42                  0           0              ggaagg                438366
# 43                  1           1               S K Y                 17186
# 44                  0           1        FC P o r t o                729116
# 45                  0           0               Tyaar               2900086
# 46                  0           0       5Ieha 3I allh                764421
# 47                  0           0          Gharafa FC               4152706
# 48                  0           0          Gharafa FC               4152706
# 49                  0           0          Gharafa FC               4152706
#
#    team_2_details_regionId team_2_details_teamId     team_2_details_stadName
# 0                  5064001                    18         Municipal de Ipurua
# 1                  5064001                    18         Municipal de Ipurua
# 2                  5064001                    18         Municipal de Ipurua
# 3                  5064001                112139              Tier 1 Stadium
# 4                  5064001                    18         Municipal de Ipurua
# 5                  4281683                    11      Heinz von Heiden-Arena
# 6                  4281683                    11      Heinz von Heiden-Arena
# 7                  4281683                    11      Heinz von Heiden-Arena
# 8                  4281683                    11      Heinz von Heiden-Arena
# 9                  4281683                    11      Heinz von Heiden-Arena
# 10                 5064001                   166       Mercedes-Benz Stadium
# 11                 5064001                    18         Municipal de Ipurua
# 12                 5064001                112139              Badiah Stadium
# 13                 5064001                    18         Municipal de Ipurua
# 14                 5064001                     9            Volkswagen Arena
# 15                 5064001                110374       Estadio José Zorrilla
# 16                 5064001                   243         Power Horse Stadium
# 17                 5064001                   243         Power Horse Stadium
# 18                 5064001                112139                Dark Stadium
# 19                 5064001                112139                Dark Stadium
# 20                 4539733                110953                    BRASILIA
# 21                 4539733                  1330            Düsseldorf-Arena
# 22                 4539733                110953                    BRASILIA
# 23                 4539733                110953                    BRASILIA
# 24                 4539733                110953                    BRASILIA
# 25                 5064001                   605              Tier 1 Stadium
# 26                 5064001                   605              Tier 1 Stadium
# 27                 5064001                   605              Tier 1 Stadium
# 28                 5064001                   605              Tier 1 Stadium
# 29                 5064001                   605              Tier 1 Stadium
# 30                 4344147                112134              The Aces Arena
# 31                 4344147                112134              The Aces Arena
# 32                 4344147                112134              The Aces Arena
# 33                 4344147                112134              The Aces Arena
# 34                 4344147                112134              The Aces Arena
# 35                 4539733                   234              Tier 3 Stadium
# 36                 4539733                  1330            Düsseldorf-Arena
# 37                 4539733                110953                    BRASILIA
# 38                 4539733                   234              Tier 3 Stadium
# 39                 4539733                   234              Tier 3 Stadium
# 40                 5064001                112139  Estadio Ciutat de València
# 41                 5064001                112387       Estadio José Zorrilla
# 42                 5064001                    73       Mercedes-Benz Stadium
# 43                 5064001                  1335              Tier 3 Stadium
# 44                 5064001                131389                     Anfield
# 45                 5064001                   241       Estadio José Zorrilla
# 46                 5064001                   243                  El Alcoraz
# 47                 5064001                112139              Tier 1 Stadium
# 48                 5064001                112139              Tier 1 Stadium
# 49                 5064001                112139              Tier 1 Stadium
#
# [50 rows x 38 columns]

# %%
json_dict
# Out:
# [{'matchId': '24932216390150',
#   'timestamp': 1700737526,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700737524',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '2',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '2900086': {'date': '1700737524',
#     'gameNumber': '0',
#     'goals': '2',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '2',
#     'season_id': '0',
#     'TEAM': '241',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Tyaar',
#      'clubId': 2900086,
#      'regionId': 5064001,
#      'teamId': 241,
#      'customKit': {'stadName': 'Estadio José Zorrilla',
#       'kitId': '1974272',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160626'}}}},
#   'players': {'2900086': {'1281893699': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '22',
#      'passesmade': '20',
#      'pos': 'midfielder',
#      'rating': '7.20',
#      'realtimegame': '949',
#      'realtimeidle': '7',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '0',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': '096|095|088|089|067|077|059|085|062|085|064|089|076|091|079|089|076|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'iLord_92'},
#     '1734355884': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '75',
#      'passesmade': '70',
#      'pos': '',
#      'rating': '6.40',
#      'realtimegame': '3533',
#      'realtimeidle': '9',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '8',
#      'tackleattempts': '36',
#      'tacklesmade': '10',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'iDvLz-121'},
#     '1984307914': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '26',
#      'passesmade': '19',
#      'pos': 'midfielder',
#      'rating': '8.10',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '2',
#      'shots': '3',
#      'tackleattempts': '4',
#      'tacklesmade': '1',
#      'vproattr': '093|088|087|085|069|072|058|085|062|083|064|087|093|093|093|089|075|079|063|091|096|065|067|077|067|065|073|098|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'Mo7ssan'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '6.90',
#      'realtimegame': '949',
#      'realtimeidle': '78',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '19',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '8.00',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '15',
#      'passesmade': '12',
#      'pos': 'midfielder',
#      'rating': '7.00',
#      'realtimegame': '949',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '10',
#      'tacklesmade': '2',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '7',
#      'passesmade': '6',
#      'pos': 'forward',
#      'rating': '8.60',
#      'realtimegame': '949',
#      'realtimeidle': '128',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '2',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '9',
#      'passesmade': '8',
#      'pos': 'midfielder',
#      'rating': '6.40',
#      'realtimegame': '949',
#      'realtimeidle': '8',
#      'redcards': '1',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '16',
#      'tacklesmade': '3',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '2',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '45',
#      'passesmade': '43',
#      'pos': '',
#      'rating': '7.10',
#      'realtimegame': '949',
#      'realtimeidle': '8',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '4',
#      'tackleattempts': '25',
#      'tacklesmade': '7',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'2900086': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 2,
#     'goalsconceded': 12,
#     'losses': 3,
#     'mom': 0,
#     'namespace': 3,
#     'passattempts': 123,
#     'passesmade': 109,
#     'pos': 0,
#     'rating': 21.7,
#     'realtimegame': 5431,
#     'realtimeidle': 26,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 6,
#     'shots': 11,
#     'tackleattempts': 43,
#     'tacklesmade': 12,
#     'vproattr': 0,
#     'vprohackreason': 16,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 12,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 107,
#     'passesmade': 93,
#     'pos': 0,
#     'rating': 44.0,
#     'realtimegame': 5694,
#     'realtimeidle': 242,
#     'redcards': 1,
#     'saves': 0,
#     'SCORE': 24,
#     'shots': 6,
#     'tackleattempts': 55,
#     'tacklesmade': 13,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24920264080311',
#   'timestamp': 1700736295,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700736294',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '764421': {'date': '1700736294',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '243',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': '5Ieha 3I allh',
#      'clubId': 764421,
#      'regionId': 5064001,
#      'teamId': 243,
#      'customKit': {'stadName': 'El Alcoraz',
#       'kitId': '1990656',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160115'}}}},
#   'players': {'764421': {'1111325960': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '6',
#      'passesmade': '4',
#      'pos': 'midfielder',
#      'rating': '5.70',
#      'realtimegame': '556',
#      'realtimeidle': '17',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '1',
#      'tackleattempts': '4',
#      'tacklesmade': '1',
#      'vproattr': 'NH',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'sq_Yi'},
#     '1845197370': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'goalkeeper',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'kq--77'},
#     '1871269370': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'Toflk-'},
#     '1930904856': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '7.60',
#      'realtimegame': '7489',
#      'realtimeidle': '33',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '078|080|089|091|070|071|059|085|063|083|064|088|093|096|091|087|081|079|064|091|091|066|072|077|068|066|073|089|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'shybmar876-shybm'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '9',
#      'passesmade': '7',
#      'pos': 'midfielder',
#      'rating': '6.40',
#      'realtimegame': '555',
#      'realtimeidle': '18',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '1',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '3',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '9.20',
#      'realtimegame': '555',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '7.30',
#      'realtimegame': '555',
#      'realtimeidle': '11',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '8',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '10',
#      'passesmade': '8',
#      'pos': 'forward',
#      'rating': '9.10',
#      'realtimegame': '555',
#      'realtimeidle': '75',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '3',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '5',
#      'pos': 'midfielder',
#      'rating': '6.20',
#      'realtimegame': '555',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '12',
#      'tacklesmade': '0',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '34',
#      'passesmade': '32',
#      'pos': '',
#      'rating': '6.90',
#      'realtimegame': '555',
#      'realtimeidle': '4',
#      'redcards': '0',
#      'saves': '1',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '11',
#      'tacklesmade': '3',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'764421': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 4,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 4,
#     'passattempts': 6,
#     'passesmade': 4,
#     'pos': 0,
#     'rating': 19.3,
#     'realtimegame': 8045,
#     'realtimeidle': 50,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 4,
#     'shots': 1,
#     'tackleattempts': 4,
#     'tacklesmade': 1,
#     'vproattr': 0,
#     'vprohackreason': 8,
#     'wins': 0},
#    '662486': {'assists': 4,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 87,
#     'passesmade': 73,
#     'pos': 0,
#     'rating': 45.1,
#     'realtimegame': 3330,
#     'realtimeidle': 124,
#     'redcards': 0,
#     'saves': 1,
#     'SCORE': 24,
#     'shots': 4,
#     'tackleattempts': 36,
#     'tacklesmade': 6,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24932193940123',
#   'timestamp': 1700735651,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700735649',
#     'gameNumber': '0',
#     'goals': '3',
#     'goalsAgainst': '0',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '3',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700735649',
#     'gameNumber': '0',
#     'goals': '0',
#     'goalsAgainst': '3',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '0',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.60',
#      'realtimegame': '77002',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.80',
#      'realtimegame': '255',
#      'realtimeidle': '14',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1007324980209': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '3',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '3',
#      'passesmade': '3',
#      'pos': 'midfielder',
#      'rating': '5.80',
#      'realtimegame': '23230',
#      'realtimeidle': '49',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'abo5ly-_-'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.70',
#      'realtimegame': '275',
#      'realtimeidle': '10',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '6.90',
#      'realtimegame': '275',
#      'realtimeidle': '37',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '3',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '7',
#      'passesmade': '5',
#      'pos': 'midfielder',
#      'rating': '9.30',
#      'realtimegame': '275',
#      'realtimeidle': '5',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '0',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '2',
#      'passesmade': '2',
#      'pos': 'midfielder',
#      'rating': '6.30',
#      'realtimegame': '275',
#      'realtimeidle': '3',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '0',
#      'tackleattempts': '3',
#      'tacklesmade': '0',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '4',
#      'passesmade': '4',
#      'pos': 'forward',
#      'rating': '7.70',
#      'realtimegame': '275',
#      'realtimeidle': '24',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '4',
#      'passesmade': '2',
#      'pos': 'midfielder',
#      'rating': '6.50',
#      'realtimegame': '275',
#      'realtimeidle': '1',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '1',
#      'tackleattempts': '2',
#      'tacklesmade': '1',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '1',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '6',
#      'pos': '',
#      'rating': '6.10',
#      'realtimegame': '275',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '3',
#      'shots': '3',
#      'tackleattempts': '11',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 3,
#     'losses': 4,
#     'mom': 0,
#     'namespace': 4,
#     'passattempts': 3,
#     'passesmade': 3,
#     'pos': 0,
#     'rating': 22.9,
#     'realtimegame': 100762,
#     'realtimeidle': 79,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 4,
#     'shots': 0,
#     'tackleattempts': 0,
#     'tacklesmade': 0,
#     'vproattr': 0,
#     'vprohackreason': 32,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 1,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 3,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 25,
#     'passesmade': 19,
#     'pos': 0,
#     'rating': 42.8,
#     'realtimegame': 1650,
#     'realtimeidle': 70,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 18,
#     'shots': 6,
#     'tackleattempts': 17,
#     'tacklesmade': 2,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24906309550476',
#   'timestamp': 1700735201,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700735200',
#     'gameNumber': '0',
#     'goals': '5',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '16385',
#     'score': '5',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '1',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700735200',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '5',
#     'losses': '1',
#     'matchType': '1',
#     'result': '10',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '5.30',
#      'realtimegame': '76378',
#      'realtimeidle': '42',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '7.80',
#      'realtimegame': '855',
#      'realtimeidle': '51',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1003778529393': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'OhhRuthless--'},
#     '1007324980209': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'forward',
#      'rating': '6.00',
#      'realtimegame': '22765',
#      'realtimeidle': '34',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'abo5ly-_-'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '5',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '11',
#      'passesmade': '9',
#      'pos': 'forward',
#      'rating': '5.90',
#      'realtimegame': '938',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '1',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '8',
#      'passesmade': '7',
#      'pos': 'midfielder',
#      'rating': '7.50',
#      'realtimegame': '938',
#      'realtimeidle': '55',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '4',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '5',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '25',
#      'passesmade': '19',
#      'pos': 'midfielder',
#      'rating': '10.00',
#      'realtimegame': '938',
#      'realtimeidle': '19',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '12',
#      'passesmade': '11',
#      'pos': 'midfielder',
#      'rating': '7.40',
#      'realtimegame': '938',
#      'realtimeidle': '35',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '12',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '916',
#      'realtimeidle': '176',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '7.90',
#      'realtimegame': '938',
#      'realtimeidle': '25',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '1',
#      'tackleattempts': '24',
#      'tacklesmade': '5',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '2',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '39',
#      'passesmade': '34',
#      'pos': '',
#      'rating': '7.00',
#      'realtimegame': '938',
#      'realtimeidle': '23',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '5',
#      'shots': '6',
#      'tackleattempts': '19',
#      'tacklesmade': '7',
#      'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 0,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 0,
#     'goalsconceded': 5,
#     'losses': 5,
#     'mom': 0,
#     'namespace': 5,
#     'passattempts': 11,
#     'passesmade': 9,
#     'pos': 0,
#     'rating': 28.0,
#     'realtimegame': 100936,
#     'realtimeidle': 146,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 5,
#     'shots': 1,
#     'tackleattempts': 1,
#     'tacklesmade': 0,
#     'vproattr': 0,
#     'vprohackreason': 32,
#     'wins': 0},
#    '662486': {'assists': 5,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 3,
#     'goalsconceded': 5,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 98,
#     'passesmade': 81,
#     'pos': 0,
#     'rating': 48.8,
#     'realtimegame': 5606,
#     'realtimeidle': 333,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 30,
#     'shots': 11,
#     'tackleattempts': 55,
#     'tacklesmade': 13,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}},
#  {'matchId': '24932154470015',
#   'timestamp': 1700734033,
#   'timeAgo': {'number': 1, 'unit': 'days'},
#   'clubs': {'662486': {'date': '1700734031',
#     'gameNumber': '0',
#     'goals': '4',
#     'goalsAgainst': '1',
#     'losses': '0',
#     'matchType': '1',
#     'result': '1',
#     'score': '4',
#     'season_id': '0',
#     'TEAM': '65',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '1',
#     'details': {'name': 'S  P  U  R  S',
#      'clubId': 662486,
#      'regionId': 5064001,
#      'teamId': 65,
#      'customKit': {'stadName': 'Estadio San Mamés',
#       'kitId': '532483',
#       'seasonalTeamId': '131397',
#       'seasonalKitId': '1076404224',
#       'selectedKitType': '0',
#       'customKitId': '7509',
#       'customAwayKitId': '7509',
#       'customThirdKitId': '7511',
#       'customKeeperKitId': '5005',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160625'}}},
#    '4152706': {'date': '1700734031',
#     'gameNumber': '0',
#     'goals': '1',
#     'goalsAgainst': '4',
#     'losses': '1',
#     'matchType': '1',
#     'result': '2',
#     'score': '1',
#     'season_id': '0',
#     'TEAM': '112139',
#     'ties': '0',
#     'winnerByDnf': '0',
#     'wins': '0',
#     'details': {'name': 'Gharafa FC',
#      'clubId': 4152706,
#      'regionId': 5064001,
#      'teamId': 112139,
#      'customKit': {'stadName': 'Tier 1 Stadium',
#       'kitId': '918642688',
#       'customKitId': '7509',
#       'kitColor1': '15921906',
#       'kitColor2': '592397',
#       'kitColor3': '592397',
#       'kitColor4': '592397',
#       'customAwayKitId': '7509',
#       'kitAColor1': '592397',
#       'kitAColor2': '15921906',
#       'kitAColor3': '15921906',
#       'kitAColor4': '15921906',
#       'customThirdKitId': '7511',
#       'kitThrdColor1': '12706617',
#       'kitThrdColor2': '33627',
#       'kitThrdColor3': '396864',
#       'kitThrdColor4': '2164288',
#       'customKeeperKitId': '5005',
#       'dCustomKit': '0',
#       'crestColor': '-1',
#       'crestAssetId': '99160327',
#       'seasonalTeamId': '0',
#       'seasonalKitId': '0',
#       'selectedKitType': '0'}}}},
#   'players': {'4152706': {'193083681': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '76',
#      'passesmade': '70',
#      'pos': '',
#      'rating': '6.00',
#      'realtimegame': '962',
#      'realtimeidle': '29',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '3',
#      'tackleattempts': '40',
#      'tacklesmade': '1',
#      'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'ronaldo990'},
#     '1873723519': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '15',
#      'passesmade': '10',
#      'pos': 'midfielder',
#      'rating': '7.90',
#      'realtimegame': '962',
#      'realtimeidle': '6',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '7',
#      'tacklesmade': '4',
#      'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'co_1j_2'},
#     '1003778529393': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': '',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'OhhRuthless--'},
#     '1005482916657': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '0',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '0',
#      'passesmade': '0',
#      'pos': '',
#      'rating': '3.00',
#      'realtimegame': '0',
#      'realtimeidle': '0',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '',
#      'vprohackreason': '0',
#      'wins': '0',
#      'playername': 'mujahid_m99'},
#     '1007976149039': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '4',
#      'losses': '1',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '11',
#      'pos': 'forward',
#      'rating': '6.20',
#      'realtimegame': '962',
#      'realtimeidle': '35',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '1',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '0',
#      'playername': 'y_a8xx'}},
#    '662486': {'1854026811': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '5',
#      'passesmade': '4',
#      'pos': 'midfielder',
#      'rating': '6.20',
#      'realtimegame': '962',
#      'realtimeidle': '42',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '0',
#      'tacklesmade': '0',
#      'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'iLoRs1-'},
#     '1960634256': {'assists': '2',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '1',
#      'namespace': '1',
#      'passattempts': '25',
#      'passesmade': '22',
#      'pos': 'midfielder',
#      'rating': '9.00',
#      'realtimegame': '962',
#      'realtimeidle': '12',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '2',
#      'tacklesmade': '1',
#      'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'lI-OsK'},
#     '1969882377': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '1',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '22',
#      'passesmade': '15',
#      'pos': 'midfielder',
#      'rating': '8.60',
#      'realtimegame': '962',
#      'realtimeidle': '14',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '2',
#      'tackleattempts': '13',
#      'tacklesmade': '1',
#      'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'AQ_DAG'},
#     '1975587038': {'assists': '1',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '14',
#      'passesmade': '13',
#      'pos': 'forward',
#      'rating': '8.00',
#      'realtimegame': '2552',
#      'realtimeidle': '101',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '3',
#      'tackleattempts': '1',
#      'tacklesmade': '0',
#      'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'k-general7'},
#     '1006200723046': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '0',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '17',
#      'passesmade': '15',
#      'pos': 'midfielder',
#      'rating': '8.00',
#      'realtimegame': '962',
#      'realtimeidle': '13',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '0',
#      'tackleattempts': '19',
#      'tacklesmade': '7',
#      'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'cMesi-'},
#     '1007590505294': {'assists': '0',
#      'cleansheetsany': '0',
#      'cleansheetsdef': '0',
#      'cleansheetsgk': '0',
#      'goals': '3',
#      'goalsconceded': '1',
#      'losses': '0',
#      'mom': '0',
#      'namespace': '1',
#      'passattempts': '34',
#      'passesmade': '33',
#      'pos': '',
#      'rating': '7.10',
#      'realtimegame': '2242',
#      'realtimeidle': '9',
#      'redcards': '0',
#      'saves': '0',
#      'SCORE': '4',
#      'shots': '10',
#      'tackleattempts': '23',
#      'tacklesmade': '5',
#      'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#      'vprohackreason': '8',
#      'wins': '1',
#      'playername': 'ByAzi_'}}},
#   'aggregate': {'4152706': {'assists': 1,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 1,
#     'goalsconceded': 12,
#     'losses': 5,
#     'mom': 0,
#     'namespace': 5,
#     'passattempts': 105,
#     'passesmade': 91,
#     'pos': 0,
#     'rating': 26.1,
#     'realtimegame': 2886,
#     'realtimeidle': 70,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 5,
#     'shots': 3,
#     'tackleattempts': 47,
#     'tacklesmade': 5,
#     'vproattr': 0,
#     'vprohackreason': 24,
#     'wins': 0},
#    '662486': {'assists': 3,
#     'cleansheetsany': 0,
#     'cleansheetsdef': 0,
#     'cleansheetsgk': 0,
#     'goals': 4,
#     'goalsconceded': 6,
#     'losses': 0,
#     'mom': 1,
#     'namespace': 6,
#     'passattempts': 117,
#     'passesmade': 102,
#     'pos': 0,
#     'rating': 46.9,
#     'realtimegame': 8642,
#     'realtimeidle': 191,
#     'redcards': 0,
#     'saves': 0,
#     'SCORE': 24,
#     'shots': 15,
#     'tackleattempts': 58,
#     'tacklesmade': 14,
#     'vproattr': 0,
#     'vprohackreason': 48,
#     'wins': 6}}}]

# %%
duck = player_build_attributes(json_dict, vproattr_key_names)

# %%
player_stat_list
# Out:
# [{'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 897712440,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 17,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 957,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 7,
#   'tackleattempts': 10,
#   'tacklesmade': 0,
#   'vproattr': '078|092|080|091|074|087|088|091|072|089|060|098|075|093|072|089|098|084|084|073|075|055|086|089|054|047|091|076|084|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'F9lrc'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1816663702,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '098|095|099|095|070|085|060|093|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|073|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'R-7hp'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1916753895,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 20,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.80',
#   'realtimegame': 1151,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '094|091|090|089|070|083|065|088|071|081|095|086|076|093|082|092|064|072|066|070|086|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lCqk'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1969806916,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 957,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 11,
#   'tacklesmade': 3,
#   'vproattr': '094|094|095|095|071|081|073|085|071|083|079|091|079|095|083|093|075|080|064|072|084|080|073|073|078|075|073|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'DKToR_i'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004757345736,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 957,
#   'realtimeidle': 57,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '094|094|075|078|077|087|077|092|086|081|095|075|082|086|085|079|066|072|068|074|089|093|063|066|088|093|065|077|072|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'SZXO_7'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004795914319,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '096|095|099|093|067|077|059|085|062|085|064|092|086|097|092|095|077|078|059|082|096|052|072|067|060|056|074|099|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'RELAX_b13'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 19017,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 2,
#   'pos': 'midfielder',
#   'rating': '7.10',
#   'realtimegame': 17642,
#   'realtimeidle': 94,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 7,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 6903,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 4367,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 8,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 1,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 29,
#   'passesmade': 26,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1679138241,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 919,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '096|093|099|089|067|082|059|089|062|085|064|086|084|084|081|093|089|084|059|079|087|052|082|081|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'k99dx'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1999200333,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 9,
#   'tacklesmade': 0,
#   'vproattr': '095|090|089|094|070|081|073|089|066|088|060|099|073|095|071|095|095|078|072|064|082|050|082|090|059|052|085|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'MO_B57'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005368319795,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 919,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 5,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|089|070|085|062|096|062|085|064|089|076|088|079|095|089|078|059|069|083|052|072|081|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'kofi__99'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005885586957,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.20',
#   'realtimegame': 8339,
#   'realtimeidle': 22,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 1,
#   'vproattr': '094|094|089|086|074|089|074|089|071|083|064|087|085|089|085|089|083|080|064|087|086|067|078|073|064|061|073|088|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'asnop_'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '6.90',
#   'realtimegame': 17066,
#   'realtimeidle': 27,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 10,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 919,
#   'realtimeidle': 40,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 23,
#   'pos': 'midfielder',
#   'rating': '8.30',
#   'realtimegame': 919,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.30',
#   'realtimegame': 919,
#   'realtimeidle': 52,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '8.50',
#   'realtimegame': 919,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 24,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 919,
#   'realtimeidle': 15,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 3,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 25,
#   'pos': 'midfielder',
#   'rating': '9.30',
#   'realtimegame': 919,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 27,
#   'pos': '',
#   'rating': '6.90',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 5,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1782831583,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 910,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 7,
#   'tacklesmade': 3,
#   'vproattr': '089|090|084|083|072|072|061|085|064|083|064|081|094|088|086|086|082|079|066|090|093|067|070|078|069|067|074|090|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Osama_pato'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1788805975,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.90',
#   'realtimegame': 5405,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 4,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '086|091|064|075|081|083|087|090|079|089|060|085|076|077|073|074|097|079|091|072|075|056|086|086|053|046|098|075|085|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lwwcl'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1865044093,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 67,
#   'passesmade': 62,
#   'pos': '',
#   'rating': '6.20',
#   'realtimegame': 910,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 8,
#   'vproattr': '080|092|063|064|081|076|086|082|085|087|086|063|067|072|072|060|065|060|092|075|077|090|073|071|086|093|062|065|066|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Jokerinho_x7'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1004393922782,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 910,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 14,
#   'tacklesmade': 1,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'iiKbees'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1005402433160,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '8.90',
#   'realtimegame': 910,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 3,
#   'vproattr': '091|096|079|083|077|082|076|085|072|083|064|079|092|085|096|082|085|081|067|090|094|068|081|083|065|062|075|095|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iiMAISTRO_o'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'forward',
#   'rating': '9.20',
#   'realtimegame': 910,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 4,
#   'tackleattempts': 6,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 127,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.00',
#   'realtimegame': 910,
#   'realtimeidle': 66,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 20,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 18,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 4,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 910,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 910,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '093|091|089|088|077|091|070|099|078|081|092|083|076|090|082|086|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 33,
#   'passesmade': 29,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 910,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 3,
#   'tackleattempts': 12,
#   'tacklesmade': 3,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '9.40',
#   'realtimegame': 895,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 4,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 6,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 88,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 1,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 16,
#   'pos': 'defender',
#   'rating': '7.50',
#   'realtimegame': 5619,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 3,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 895,
#   'realtimeidle': 26,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 6823,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 42,
#   'passesmade': 35,
#   'pos': '',
#   'rating': '6.70',
#   'realtimegame': 895,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 17,
#   'tacklesmade': 4,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1699768971,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 20,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 895,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 6,
#   'vproattr': '096|093|084|077|073|091|073|099|084|081|095|076|076|083|082|080|064|072|066|070|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'I_TurkiGh'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1877952460,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 6,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 895,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 5,
#   'tackleattempts': 8,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'c6-nE'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1940280576,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '7.70',
#   'realtimegame': 895,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 16,
#   'tacklesmade': 3,
#   'vproattr': '098|091|099|089|067|077|059|085|062|085|064|089|086|091|090|097|076|091|059|082|089|052|082|067|060|056|074|092|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 's_albalwi818'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1005134793307,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 895,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '096|093|090|089|070|091|062|089|071|081|088|083|076|093|082|090|064|072|066|070|091|092|061|064|087|087|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iMellR'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1006417720454,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 52,
#   'passesmade': 47,
#   'pos': '',
#   'rating': '5.90',
#   'realtimegame': 895,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 4,
#   'vproattr': '098|095|093|086|067|077|059|085|062|085|064|085|076|091|079|085|089|078|059|067|081|052|067|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ZAhmed500'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1630571838,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 82,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '081|085|054|060|090|089|095|094|099|087|094|063|071|069|071|059|067|061|097|068|075|099|070|070|092|095|066|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cILuiz'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1754361157,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 12,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 985,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '092|095|086|079|076|089|076|099|078|081|094|083|078|082|084|084|068|072|070|066|080|091|065|068|089|087|066|076|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ixMz3j'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1793967602,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 18,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 2,
#   'vproattr': '091|093|095|082|068|078|060|085|063|085|064|085|089|091|092|095|076|095|060|083|093|053|080|069|061|057|075|099|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cTh1--'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1804397559,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'midfielder',
#   'rating': '6.30',
#   'realtimegame': 986,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '091|096|085|078|076|085|073|092|074|081|096|081|076|086|083|083|069|073|071|071|087|093|066|069|089|093|069|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'alda6060'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 23,
#   'tacklesmade': 8,
#   'vproattr': '090|094|093|087|073|083|086|088|080|083|076|088|078|088|084|088|076|080|066|076|082|079|075|075|080|067|074|078|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 2000612994,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 15,
#   'pos': 'forward',
#   'rating': '8.10',
#   'realtimegame': 985,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 4,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|072|060|056|080|083|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cKlwa'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1003966668622,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 45,
#   'passesmade': 38,
#   'pos': '',
#   'rating': '6.80',
#   'realtimegame': 986,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|099|095|070|085|059|093|062|085|064|092|076|097|079|099|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cFLcaw'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 985,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AKIJ-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 986,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 30,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'KH2vz'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 985,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cMesi-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 23,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 986,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'X20X'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 986,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'O-D'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 38,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'yKaneL'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1736817133,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '5.80',
#   'realtimegame': 30,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'xMGdd-'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1004370337600,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '4.70',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '054|068|032|056|065|048|060|085|040|060|020|020|045|020|025|015|020|020|015|040|040|020|061|015|020|020|015|030|035|090|097|097|096|099|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'M9H3I'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25196195260448,
#   'teamId': 2018971,
# ...
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 3,
#   'passesmade': 3,
#   'pos': 'midfielder',
#   'rating': '5.80',
#   'realtimegame': 23230,
#   'realtimeidle': 49,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24932193940123,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 275,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 938,
#   'realtimeidle': 55,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 4,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 5,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '10.00',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.40',
#   'realtimegame': 938,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 916,
#   'realtimeidle': 176,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 938,
#   'realtimeidle': 25,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 39,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '7.00',
#   'realtimegame': 938,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 6,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.30',
#   'realtimegame': 76378,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 855,
#   'realtimeidle': 51,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007324980209,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'forward',
#   'rating': '6.00',
#   'realtimegame': 22765,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '5.90',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 5,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 962,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 962,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 2,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 13,
#   'pos': 'forward',
#   'rating': '8.00',
#   'realtimegame': 2552,
#   'realtimeidle': 101,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 3,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 962,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 34,
#   'passesmade': 33,
#   'pos': '',
#   'rating': '7.10',
#   'realtimegame': 2242,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 10,
#   'tackleattempts': 23,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 76,
#   'passesmade': 70,
#   'pos': '',
#   'rating': '6.00',
#   'realtimegame': 962,
#   'realtimeidle': 29,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 3,
#   'tackleattempts': 40,
#   'tacklesmade': 1,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 962,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 7,
#   'tacklesmade': 4,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1005482916657,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'mujahid_m99'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 11,
#   'pos': 'forward',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'}]

# %%
player_stat_list_df = pd.DataFrame(player_stat_list)

# %%
player_stat_list_df
# Out:
#             matchId   teamId       playerId  assists  cleansheetsany  \
# 0    25182250910116    26401      897712440        0               0
# 1    25182250910116    26401     1816663702        0               0
# 2    25182250910116    26401     1916753895        0               0
# 3    25182250910116    26401     1969806916        0               0
# 4    25182250910116    26401  1004757345736        0               0
# ..              ...      ...            ...      ...             ...
# 534  24932154470015  4152706      193083681        0               0
# 535  24932154470015  4152706     1873723519        1               0
# 536  24932154470015  4152706  1003778529393        0               0
# 537  24932154470015  4152706  1005482916657        0               0
# 538  24932154470015  4152706  1007976149039        0               0
#
#      cleansheetsdef  cleansheetsgk  goals  goalsconceded  losses  ...  \
# 0                 0              0      0              2       1  ...
# 1                 0              0      0              2       1  ...
# 2                 0              0      0              2       1  ...
# 3                 0              0      0              2       1  ...
# 4                 0              0      0              2       1  ...
# ..              ...            ...    ...            ...     ...  ...
# 534               0              0      1              4       1  ...
# 535               0              0      0              4       1  ...
# 536               0              0      0              0       1  ...
# 537               0              0      0              0       1  ...
# 538               0              0      0              4       1  ...
#
#      redcards  saves  SCORE  shots tackleattempts tacklesmade  \
# 0           0      0      0      7             10           0
# 1           0      0      0      3              8           3
# 2           0      0      0      0             15           2
# 3           0      0      0      0             11           3
# 4           0      0      0      0              3           0
# ..        ...    ...    ...    ...            ...         ...
# 534         0      0      1      3             40           1
# 535         0      0      1      0              7           4
# 536         0      0      1      0              0           0
# 537         0      0      1      0              0           0
# 538         0      0      1      0              0           0
#
#                                               vproattr  vprohackreason  wins  \
# 0    078|092|080|091|074|087|088|091|072|089|060|09...               8     0
# 1    098|095|099|095|070|085|060|093|062|085|064|09...               8     0
# 2    094|091|090|089|070|083|065|088|071|081|095|08...               8     0
# 3    094|094|095|095|071|081|073|085|071|083|079|09...               8     0
# 4    094|094|075|078|077|087|077|092|086|081|095|07...               8     0
# ..                                                 ...             ...   ...
# 534  094|091|082|094|071|076|074|085|066|088|060|09...               8     0
# 535  098|095|099|087|067|077|059|085|062|085|064|09...               8     0
# 536                                                                  0     0
# 537                                                                  0     0
# 538  093|091|072|080|075|086|081|099|071|088|060|08...               8     0
#
#         playername
# 0            F9lrc
# 1            R-7hp
# 2             lCqk
# 3          DKToR_i
# 4           SZXO_7
# ..             ...
# 534     ronaldo990
# 535        co_1j_2
# 536  OhhRuthless--
# 537    mujahid_m99
# 538         y_a8xx
#
# [539 rows x 28 columns]

# %%
player_stat_list
# Out:
# [{'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 897712440,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 17,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 957,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 7,
#   'tackleattempts': 10,
#   'tacklesmade': 0,
#   'vproattr': '078|092|080|091|074|087|088|091|072|089|060|098|075|093|072|089|098|084|084|073|075|055|086|089|054|047|091|076|084|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'F9lrc'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1816663702,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '098|095|099|095|070|085|060|093|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|073|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'R-7hp'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1916753895,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 20,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.80',
#   'realtimegame': 1151,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '094|091|090|089|070|083|065|088|071|081|095|086|076|093|082|092|064|072|066|070|086|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lCqk'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1969806916,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 957,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 11,
#   'tacklesmade': 3,
#   'vproattr': '094|094|095|095|071|081|073|085|071|083|079|091|079|095|083|093|075|080|064|072|084|080|073|073|078|075|073|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'DKToR_i'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004757345736,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 957,
#   'realtimeidle': 57,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '094|094|075|078|077|087|077|092|086|081|095|075|082|086|085|079|066|072|068|074|089|093|063|066|088|093|065|077|072|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'SZXO_7'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004795914319,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '096|095|099|093|067|077|059|085|062|085|064|092|086|097|092|095|077|078|059|082|096|052|072|067|060|056|074|099|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'RELAX_b13'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 19017,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 2,
#   'pos': 'midfielder',
#   'rating': '7.10',
#   'realtimegame': 17642,
#   'realtimeidle': 94,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 7,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 6903,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 4367,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 8,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 1,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 29,
#   'passesmade': 26,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1679138241,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 919,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '096|093|099|089|067|082|059|089|062|085|064|086|084|084|081|093|089|084|059|079|087|052|082|081|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'k99dx'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1999200333,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 9,
#   'tacklesmade': 0,
#   'vproattr': '095|090|089|094|070|081|073|089|066|088|060|099|073|095|071|095|095|078|072|064|082|050|082|090|059|052|085|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'MO_B57'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005368319795,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 919,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 5,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|089|070|085|062|096|062|085|064|089|076|088|079|095|089|078|059|069|083|052|072|081|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'kofi__99'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005885586957,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.20',
#   'realtimegame': 8339,
#   'realtimeidle': 22,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 1,
#   'vproattr': '094|094|089|086|074|089|074|089|071|083|064|087|085|089|085|089|083|080|064|087|086|067|078|073|064|061|073|088|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'asnop_'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '6.90',
#   'realtimegame': 17066,
#   'realtimeidle': 27,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 10,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 919,
#   'realtimeidle': 40,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 23,
#   'pos': 'midfielder',
#   'rating': '8.30',
#   'realtimegame': 919,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.30',
#   'realtimegame': 919,
#   'realtimeidle': 52,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '8.50',
#   'realtimegame': 919,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 24,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 919,
#   'realtimeidle': 15,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 3,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 25,
#   'pos': 'midfielder',
#   'rating': '9.30',
#   'realtimegame': 919,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 27,
#   'pos': '',
#   'rating': '6.90',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 5,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1782831583,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 910,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 7,
#   'tacklesmade': 3,
#   'vproattr': '089|090|084|083|072|072|061|085|064|083|064|081|094|088|086|086|082|079|066|090|093|067|070|078|069|067|074|090|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Osama_pato'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1788805975,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.90',
#   'realtimegame': 5405,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 4,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '086|091|064|075|081|083|087|090|079|089|060|085|076|077|073|074|097|079|091|072|075|056|086|086|053|046|098|075|085|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lwwcl'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1865044093,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 67,
#   'passesmade': 62,
#   'pos': '',
#   'rating': '6.20',
#   'realtimegame': 910,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 8,
#   'vproattr': '080|092|063|064|081|076|086|082|085|087|086|063|067|072|072|060|065|060|092|075|077|090|073|071|086|093|062|065|066|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Jokerinho_x7'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1004393922782,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 910,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 14,
#   'tacklesmade': 1,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'iiKbees'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1005402433160,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '8.90',
#   'realtimegame': 910,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 3,
#   'vproattr': '091|096|079|083|077|082|076|085|072|083|064|079|092|085|096|082|085|081|067|090|094|068|081|083|065|062|075|095|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iiMAISTRO_o'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'forward',
#   'rating': '9.20',
#   'realtimegame': 910,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 4,
#   'tackleattempts': 6,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 127,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.00',
#   'realtimegame': 910,
#   'realtimeidle': 66,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 20,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 18,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 4,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 910,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 910,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '093|091|089|088|077|091|070|099|078|081|092|083|076|090|082|086|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 33,
#   'passesmade': 29,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 910,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 3,
#   'tackleattempts': 12,
#   'tacklesmade': 3,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '9.40',
#   'realtimegame': 895,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 4,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 6,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 88,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 1,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 16,
#   'pos': 'defender',
#   'rating': '7.50',
#   'realtimegame': 5619,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 3,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 895,
#   'realtimeidle': 26,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 6823,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 42,
#   'passesmade': 35,
#   'pos': '',
#   'rating': '6.70',
#   'realtimegame': 895,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 17,
#   'tacklesmade': 4,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1699768971,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 20,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 895,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 6,
#   'vproattr': '096|093|084|077|073|091|073|099|084|081|095|076|076|083|082|080|064|072|066|070|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'I_TurkiGh'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1877952460,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 6,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 895,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 5,
#   'tackleattempts': 8,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'c6-nE'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1940280576,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '7.70',
#   'realtimegame': 895,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 16,
#   'tacklesmade': 3,
#   'vproattr': '098|091|099|089|067|077|059|085|062|085|064|089|086|091|090|097|076|091|059|082|089|052|082|067|060|056|074|092|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 's_albalwi818'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1005134793307,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 895,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '096|093|090|089|070|091|062|089|071|081|088|083|076|093|082|090|064|072|066|070|091|092|061|064|087|087|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iMellR'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1006417720454,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 52,
#   'passesmade': 47,
#   'pos': '',
#   'rating': '5.90',
#   'realtimegame': 895,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 4,
#   'vproattr': '098|095|093|086|067|077|059|085|062|085|064|085|076|091|079|085|089|078|059|067|081|052|067|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ZAhmed500'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1630571838,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 82,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '081|085|054|060|090|089|095|094|099|087|094|063|071|069|071|059|067|061|097|068|075|099|070|070|092|095|066|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cILuiz'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1754361157,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 12,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 985,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '092|095|086|079|076|089|076|099|078|081|094|083|078|082|084|084|068|072|070|066|080|091|065|068|089|087|066|076|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ixMz3j'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1793967602,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 18,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 2,
#   'vproattr': '091|093|095|082|068|078|060|085|063|085|064|085|089|091|092|095|076|095|060|083|093|053|080|069|061|057|075|099|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cTh1--'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1804397559,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'midfielder',
#   'rating': '6.30',
#   'realtimegame': 986,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '091|096|085|078|076|085|073|092|074|081|096|081|076|086|083|083|069|073|071|071|087|093|066|069|089|093|069|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'alda6060'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 23,
#   'tacklesmade': 8,
#   'vproattr': '090|094|093|087|073|083|086|088|080|083|076|088|078|088|084|088|076|080|066|076|082|079|075|075|080|067|074|078|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 2000612994,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 15,
#   'pos': 'forward',
#   'rating': '8.10',
#   'realtimegame': 985,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 4,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|072|060|056|080|083|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cKlwa'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1003966668622,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 45,
#   'passesmade': 38,
#   'pos': '',
#   'rating': '6.80',
#   'realtimegame': 986,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|099|095|070|085|059|093|062|085|064|092|076|097|079|099|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cFLcaw'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 985,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AKIJ-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 986,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 30,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'KH2vz'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 985,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cMesi-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 23,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 986,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'X20X'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 986,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'O-D'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 38,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'yKaneL'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1736817133,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '5.80',
#   'realtimegame': 30,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'xMGdd-'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1004370337600,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '4.70',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '054|068|032|056|065|048|060|085|040|060|020|020|045|020|025|015|020|020|015|040|040|020|061|015|020|020|015|030|035|090|097|097|096|099|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'M9H3I'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25196195260448,
#   'teamId': 2018971,
# ...
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 3,
#   'passesmade': 3,
#   'pos': 'midfielder',
#   'rating': '5.80',
#   'realtimegame': 23230,
#   'realtimeidle': 49,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24932193940123,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 275,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 938,
#   'realtimeidle': 55,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 4,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 5,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '10.00',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.40',
#   'realtimegame': 938,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 916,
#   'realtimeidle': 176,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 938,
#   'realtimeidle': 25,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 39,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '7.00',
#   'realtimegame': 938,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 6,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.30',
#   'realtimegame': 76378,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 855,
#   'realtimeidle': 51,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007324980209,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'forward',
#   'rating': '6.00',
#   'realtimegame': 22765,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '5.90',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 5,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 962,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 962,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 2,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 13,
#   'pos': 'forward',
#   'rating': '8.00',
#   'realtimegame': 2552,
#   'realtimeidle': 101,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 3,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 962,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 34,
#   'passesmade': 33,
#   'pos': '',
#   'rating': '7.10',
#   'realtimegame': 2242,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 10,
#   'tackleattempts': 23,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 76,
#   'passesmade': 70,
#   'pos': '',
#   'rating': '6.00',
#   'realtimegame': 962,
#   'realtimeidle': 29,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 3,
#   'tackleattempts': 40,
#   'tacklesmade': 1,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 962,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 7,
#   'tacklesmade': 4,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1005482916657,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'mujahid_m99'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 11,
#   'pos': 'forward',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'}]

# %%
DUCKS = player_data_collect(json_dict)

# %%
player_stat_list
# Out:
# [{'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 897712440,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 17,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 957,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 7,
#   'tackleattempts': 10,
#   'tacklesmade': 0,
#   'vproattr': '078|092|080|091|074|087|088|091|072|089|060|098|075|093|072|089|098|084|084|073|075|055|086|089|054|047|091|076|084|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'F9lrc'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1816663702,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '098|095|099|095|070|085|060|093|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|073|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'R-7hp'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1916753895,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 20,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.80',
#   'realtimegame': 1151,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '094|091|090|089|070|083|065|088|071|081|095|086|076|093|082|092|064|072|066|070|086|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lCqk'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1969806916,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 957,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 11,
#   'tacklesmade': 3,
#   'vproattr': '094|094|095|095|071|081|073|085|071|083|079|091|079|095|083|093|075|080|064|072|084|080|073|073|078|075|073|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'DKToR_i'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004757345736,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 957,
#   'realtimeidle': 57,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '094|094|075|078|077|087|077|092|086|081|095|075|082|086|085|079|066|072|068|074|089|093|063|066|088|093|065|077|072|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'SZXO_7'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004795914319,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '096|095|099|093|067|077|059|085|062|085|064|092|086|097|092|095|077|078|059|082|096|052|072|067|060|056|074|099|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'RELAX_b13'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 19017,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 2,
#   'pos': 'midfielder',
#   'rating': '7.10',
#   'realtimegame': 17642,
#   'realtimeidle': 94,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 7,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 6903,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 4367,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 8,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 1,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 29,
#   'passesmade': 26,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1679138241,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 919,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '096|093|099|089|067|082|059|089|062|085|064|086|084|084|081|093|089|084|059|079|087|052|082|081|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'k99dx'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1999200333,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 9,
#   'tacklesmade': 0,
#   'vproattr': '095|090|089|094|070|081|073|089|066|088|060|099|073|095|071|095|095|078|072|064|082|050|082|090|059|052|085|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'MO_B57'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005368319795,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 919,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 5,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|089|070|085|062|096|062|085|064|089|076|088|079|095|089|078|059|069|083|052|072|081|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'kofi__99'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005885586957,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.20',
#   'realtimegame': 8339,
#   'realtimeidle': 22,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 1,
#   'vproattr': '094|094|089|086|074|089|074|089|071|083|064|087|085|089|085|089|083|080|064|087|086|067|078|073|064|061|073|088|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'asnop_'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '6.90',
#   'realtimegame': 17066,
#   'realtimeidle': 27,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 10,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 919,
#   'realtimeidle': 40,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 23,
#   'pos': 'midfielder',
#   'rating': '8.30',
#   'realtimegame': 919,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.30',
#   'realtimegame': 919,
#   'realtimeidle': 52,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '8.50',
#   'realtimegame': 919,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 24,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 919,
#   'realtimeidle': 15,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 3,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 25,
#   'pos': 'midfielder',
#   'rating': '9.30',
#   'realtimegame': 919,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 27,
#   'pos': '',
#   'rating': '6.90',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 5,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1782831583,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 910,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 7,
#   'tacklesmade': 3,
#   'vproattr': '089|090|084|083|072|072|061|085|064|083|064|081|094|088|086|086|082|079|066|090|093|067|070|078|069|067|074|090|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Osama_pato'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1788805975,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.90',
#   'realtimegame': 5405,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 4,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '086|091|064|075|081|083|087|090|079|089|060|085|076|077|073|074|097|079|091|072|075|056|086|086|053|046|098|075|085|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lwwcl'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1865044093,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 67,
#   'passesmade': 62,
#   'pos': '',
#   'rating': '6.20',
#   'realtimegame': 910,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 8,
#   'vproattr': '080|092|063|064|081|076|086|082|085|087|086|063|067|072|072|060|065|060|092|075|077|090|073|071|086|093|062|065|066|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Jokerinho_x7'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1004393922782,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 910,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 14,
#   'tacklesmade': 1,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'iiKbees'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1005402433160,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '8.90',
#   'realtimegame': 910,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 3,
#   'vproattr': '091|096|079|083|077|082|076|085|072|083|064|079|092|085|096|082|085|081|067|090|094|068|081|083|065|062|075|095|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iiMAISTRO_o'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'forward',
#   'rating': '9.20',
#   'realtimegame': 910,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 4,
#   'tackleattempts': 6,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 127,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.00',
#   'realtimegame': 910,
#   'realtimeidle': 66,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 20,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 18,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 4,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 910,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 910,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '093|091|089|088|077|091|070|099|078|081|092|083|076|090|082|086|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 33,
#   'passesmade': 29,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 910,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 3,
#   'tackleattempts': 12,
#   'tacklesmade': 3,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '9.40',
#   'realtimegame': 895,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 4,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 6,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 88,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 1,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 16,
#   'pos': 'defender',
#   'rating': '7.50',
#   'realtimegame': 5619,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 3,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 895,
#   'realtimeidle': 26,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 6823,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 42,
#   'passesmade': 35,
#   'pos': '',
#   'rating': '6.70',
#   'realtimegame': 895,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 17,
#   'tacklesmade': 4,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1699768971,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 20,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 895,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 6,
#   'vproattr': '096|093|084|077|073|091|073|099|084|081|095|076|076|083|082|080|064|072|066|070|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'I_TurkiGh'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1877952460,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 6,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 895,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 5,
#   'tackleattempts': 8,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'c6-nE'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1940280576,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '7.70',
#   'realtimegame': 895,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 16,
#   'tacklesmade': 3,
#   'vproattr': '098|091|099|089|067|077|059|085|062|085|064|089|086|091|090|097|076|091|059|082|089|052|082|067|060|056|074|092|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 's_albalwi818'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1005134793307,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 895,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '096|093|090|089|070|091|062|089|071|081|088|083|076|093|082|090|064|072|066|070|091|092|061|064|087|087|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iMellR'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1006417720454,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 52,
#   'passesmade': 47,
#   'pos': '',
#   'rating': '5.90',
#   'realtimegame': 895,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 4,
#   'vproattr': '098|095|093|086|067|077|059|085|062|085|064|085|076|091|079|085|089|078|059|067|081|052|067|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ZAhmed500'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1630571838,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 82,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '081|085|054|060|090|089|095|094|099|087|094|063|071|069|071|059|067|061|097|068|075|099|070|070|092|095|066|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cILuiz'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1754361157,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 12,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 985,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '092|095|086|079|076|089|076|099|078|081|094|083|078|082|084|084|068|072|070|066|080|091|065|068|089|087|066|076|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ixMz3j'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1793967602,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 18,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 2,
#   'vproattr': '091|093|095|082|068|078|060|085|063|085|064|085|089|091|092|095|076|095|060|083|093|053|080|069|061|057|075|099|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cTh1--'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1804397559,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'midfielder',
#   'rating': '6.30',
#   'realtimegame': 986,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '091|096|085|078|076|085|073|092|074|081|096|081|076|086|083|083|069|073|071|071|087|093|066|069|089|093|069|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'alda6060'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 23,
#   'tacklesmade': 8,
#   'vproattr': '090|094|093|087|073|083|086|088|080|083|076|088|078|088|084|088|076|080|066|076|082|079|075|075|080|067|074|078|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 2000612994,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 15,
#   'pos': 'forward',
#   'rating': '8.10',
#   'realtimegame': 985,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 4,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|072|060|056|080|083|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cKlwa'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1003966668622,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 45,
#   'passesmade': 38,
#   'pos': '',
#   'rating': '6.80',
#   'realtimegame': 986,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|099|095|070|085|059|093|062|085|064|092|076|097|079|099|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cFLcaw'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 985,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AKIJ-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 986,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 30,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'KH2vz'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 985,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cMesi-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 23,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 986,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'X20X'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 986,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'O-D'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 38,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'yKaneL'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1736817133,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '5.80',
#   'realtimegame': 30,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'xMGdd-'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1004370337600,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '4.70',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '054|068|032|056|065|048|060|085|040|060|020|020|045|020|025|015|020|020|015|040|040|020|061|015|020|020|015|030|035|090|097|097|096|099|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'M9H3I'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25196195260448,
#   'teamId': 2018971,
# ...
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 3,
#   'passesmade': 3,
#   'pos': 'midfielder',
#   'rating': '5.80',
#   'realtimegame': 23230,
#   'realtimeidle': 49,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24932193940123,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 275,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 938,
#   'realtimeidle': 55,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 4,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 5,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '10.00',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.40',
#   'realtimegame': 938,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 916,
#   'realtimeidle': 176,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 938,
#   'realtimeidle': 25,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 39,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '7.00',
#   'realtimegame': 938,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 6,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.30',
#   'realtimegame': 76378,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 855,
#   'realtimeidle': 51,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007324980209,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'forward',
#   'rating': '6.00',
#   'realtimegame': 22765,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '5.90',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 5,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 962,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 962,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 2,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 13,
#   'pos': 'forward',
#   'rating': '8.00',
#   'realtimegame': 2552,
#   'realtimeidle': 101,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 3,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 962,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 34,
#   'passesmade': 33,
#   'pos': '',
#   'rating': '7.10',
#   'realtimegame': 2242,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 10,
#   'tackleattempts': 23,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 76,
#   'passesmade': 70,
#   'pos': '',
#   'rating': '6.00',
#   'realtimegame': 962,
#   'realtimeidle': 29,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 3,
#   'tackleattempts': 40,
#   'tacklesmade': 1,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 962,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 7,
#   'tacklesmade': 4,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1005482916657,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'mujahid_m99'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 11,
#   'pos': 'forward',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'}]

# %%
player_stat_list
# Out:
# [{'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 897712440,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 17,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 957,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 7,
#   'tackleattempts': 10,
#   'tacklesmade': 0,
#   'vproattr': '078|092|080|091|074|087|088|091|072|089|060|098|075|093|072|089|098|084|084|073|075|055|086|089|054|047|091|076|084|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'F9lrc'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1816663702,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '098|095|099|095|070|085|060|093|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|073|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'R-7hp'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1916753895,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 20,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.80',
#   'realtimegame': 1151,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '094|091|090|089|070|083|065|088|071|081|095|086|076|093|082|092|064|072|066|070|086|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lCqk'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1969806916,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 957,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 11,
#   'tacklesmade': 3,
#   'vproattr': '094|094|095|095|071|081|073|085|071|083|079|091|079|095|083|093|075|080|064|072|084|080|073|073|078|075|073|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'DKToR_i'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004757345736,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 957,
#   'realtimeidle': 57,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '094|094|075|078|077|087|077|092|086|081|095|075|082|086|085|079|066|072|068|074|089|093|063|066|088|093|065|077|072|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'SZXO_7'},
#  {'matchId': 25182250910116,
#   'teamId': 26401,
#   'playerId': 1004795914319,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 1,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '096|095|099|093|067|077|059|085|062|085|064|092|086|097|092|095|077|078|059|082|096|052|072|067|060|056|074|099|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'RELAX_b13'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 19017,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 2,
#   'pos': 'midfielder',
#   'rating': '7.10',
#   'realtimegame': 17642,
#   'realtimeidle': 94,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '6.70',
#   'realtimegame': 957,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 1,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 7,
#   'pos': 'forward',
#   'rating': '6.30',
#   'realtimegame': 6903,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 4367,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 957,
#   'realtimeidle': 8,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25182250910116,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 1,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 29,
#   'passesmade': 26,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 957,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1679138241,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 919,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 11,
#   'tacklesmade': 2,
#   'vproattr': '096|093|099|089|067|082|059|089|062|085|064|086|084|084|081|093|089|084|059|079|087|052|082|081|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'k99dx'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1999200333,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 9,
#   'tacklesmade': 0,
#   'vproattr': '095|090|089|094|070|081|073|089|066|088|060|099|073|095|071|095|095|078|072|064|082|050|082|090|059|052|085|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'MO_B57'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005368319795,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 919,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 3,
#   'tackleattempts': 5,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|089|070|085|062|096|062|085|064|089|076|088|079|095|089|078|059|069|083|052|072|081|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'kofi__99'},
#  {'matchId': 25156461070308,
#   'teamId': 2590531,
#   'playerId': 1005885586957,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '7.20',
#   'realtimegame': 8339,
#   'realtimeidle': 22,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 1,
#   'vproattr': '094|094|089|086|074|089|074|089|071|083|064|087|085|089|085|089|083|080|064|087|086|067|078|073|064|061|073|088|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'asnop_'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'defender',
#   'rating': '6.90',
#   'realtimegame': 17066,
#   'realtimeidle': 27,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|088|074|091|067|096|072|081|088|083|076|093|082|086|065|072|067|069|083|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 10,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 919,
#   'realtimeidle': 40,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1960634256,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 23,
#   'pos': 'midfielder',
#   'rating': '8.30',
#   'realtimegame': 919,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '093|094|087|086|073|087|071|092|074|081|089|083|077|089|083|089|067|072|069|069|081|093|064|067|088|093|065|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1980339908,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.30',
#   'realtimegame': 919,
#   'realtimeidle': 52,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 1,
#   'vproattr': '096|093|084|078|073|091|062|089|071|081|095|079|076|087|084|084|065|072|066|079|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iBe-22'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1004344523930,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 13,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '8.50',
#   'realtimegame': 919,
#   'realtimeidle': 17,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 3,
#   'tackleattempts': 8,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|092|070|085|062|096|062|085|064|089|076|097|079|097|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iTRK10'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 24,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 919,
#   'realtimeidle': 15,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 3,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 25,
#   'pos': 'midfielder',
#   'rating': '9.30',
#   'realtimegame': 919,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 25156461070308,
#   'teamId': 3084976,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 28,
#   'passesmade': 27,
#   'pos': '',
#   'rating': '6.90',
#   'realtimegame': 919,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 5,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|096|090|070|085|065|099|065|085|064|089|076|097|079|095|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1782831583,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 910,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 7,
#   'tacklesmade': 3,
#   'vproattr': '089|090|084|083|072|072|061|085|064|083|064|081|094|088|086|086|082|079|066|090|093|067|070|078|069|067|074|090|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Osama_pato'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1788805975,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'forward',
#   'rating': '7.90',
#   'realtimegame': 5405,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 4,
#   'tackleattempts': 2,
#   'tacklesmade': 0,
#   'vproattr': '086|091|064|075|081|083|087|090|079|089|060|085|076|077|073|074|097|079|091|072|075|056|086|086|053|046|098|075|085|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'lwwcl'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1865044093,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 67,
#   'passesmade': 62,
#   'pos': '',
#   'rating': '6.20',
#   'realtimegame': 910,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 8,
#   'vproattr': '080|092|063|064|081|076|086|082|085|087|086|063|067|072|072|060|065|060|092|075|077|090|073|071|086|093|062|065|066|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'Jokerinho_x7'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1004393922782,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 910,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 2,
#   'tackleattempts': 14,
#   'tacklesmade': 1,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'iiKbees'},
#  {'matchId': 24860304270416,
#   'teamId': 2748486,
#   'playerId': 1005402433160,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 6,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 32,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '8.90',
#   'realtimegame': 910,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 2,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 3,
#   'vproattr': '091|096|079|083|077|082|076|085|072|083|064|079|092|085|096|082|085|081|067|090|094|068|081|083|065|062|075|095|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iiMAISTRO_o'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'forward',
#   'rating': '9.20',
#   'realtimegame': 910,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 4,
#   'tackleattempts': 6,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 127,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '7.00',
#   'realtimegame': 910,
#   'realtimeidle': 66,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'midfielder',
#   'rating': '6.60',
#   'realtimegame': 910,
#   'realtimeidle': 20,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 0,
#   'tackleattempts': 18,
#   'tacklesmade': 1,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 4,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 910,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 910,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 1,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '093|091|089|088|077|091|070|099|078|081|092|083|076|090|082|086|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24860304270416,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 2,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 33,
#   'passesmade': 29,
#   'pos': '',
#   'rating': '7.20',
#   'realtimegame': 910,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 6,
#   'shots': 3,
#   'tackleattempts': 12,
#   'tacklesmade': 3,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 5,
#   'pos': 'forward',
#   'rating': '9.40',
#   'realtimegame': 895,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 4,
#   'tackleattempts': 5,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AKIJ-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 6,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 88,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 1,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 16,
#   'pos': 'defender',
#   'rating': '7.50',
#   'realtimegame': 5619,
#   'realtimeidle': 36,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 3,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'KH2vz'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 8,
#   'pos': 'midfielder',
#   'rating': '6.50',
#   'realtimegame': 895,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '8.10',
#   'realtimegame': 895,
#   'realtimeidle': 26,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 3,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'X20X'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 6823,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 20,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'O-D'},
#  {'matchId': 24812847840410,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 42,
#   'passesmade': 35,
#   'pos': '',
#   'rating': '6.70',
#   'realtimegame': 895,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 17,
#   'tacklesmade': 4,
#   'vproattr': '098|095|096|095|070|085|059|093|062|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'yKaneL'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1699768971,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 20,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 895,
#   'realtimeidle': 4,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 6,
#   'vproattr': '096|093|084|077|073|091|073|099|084|081|095|076|076|083|082|080|064|072|066|070|091|092|061|064|087|091|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'I_TurkiGh'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1877952460,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 9,
#   'passesmade': 6,
#   'pos': 'forward',
#   'rating': '7.00',
#   'realtimegame': 895,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 5,
#   'tackleattempts': 8,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'c6-nE'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1940280576,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 26,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '7.70',
#   'realtimegame': 895,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 16,
#   'tacklesmade': 3,
#   'vproattr': '098|091|099|089|067|077|059|085|062|085|064|089|086|091|090|097|076|091|059|082|089|052|082|067|060|056|074|092|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 's_albalwi818'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1005134793307,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '7.30',
#   'realtimegame': 895,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 8,
#   'tacklesmade': 3,
#   'vproattr': '096|093|090|089|070|091|062|089|071|081|088|083|076|093|082|090|064|072|066|070|091|092|061|064|087|087|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iMellR'},
#  {'matchId': 24812847840410,
#   'teamId': 4071716,
#   'playerId': 1006417720454,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 52,
#   'passesmade': 47,
#   'pos': '',
#   'rating': '5.90',
#   'realtimegame': 895,
#   'realtimeidle': 1,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 6,
#   'tacklesmade': 4,
#   'vproattr': '098|095|093|086|067|077|059|085|062|085|064|085|076|091|079|085|089|078|059|067|081|052|067|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ZAhmed500'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1630571838,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 7,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 82,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '081|085|054|060|090|089|095|094|099|087|094|063|071|069|071|059|067|061|097|068|075|099|070|070|092|095|066|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cILuiz'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1754361157,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 16,
#   'passesmade': 12,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 985,
#   'realtimeidle': 7,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '092|095|086|079|076|089|076|099|078|081|094|083|078|082|084|084|068|072|070|066|080|091|065|068|089|087|066|076|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ixMz3j'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1793967602,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 18,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 11,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 2,
#   'vproattr': '091|093|095|082|068|078|060|085|063|085|064|085|089|091|092|095|076|095|060|083|093|053|080|069|061|057|075|099|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cTh1--'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1804397559,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 13,
#   'pos': 'midfielder',
#   'rating': '6.30',
#   'realtimegame': 986,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 6,
#   'tacklesmade': 2,
#   'vproattr': '091|096|085|078|076|085|073|092|074|081|096|081|076|086|083|083|069|073|071|071|087|093|066|069|089|093|069|077|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'alda6060'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 24,
#   'passesmade': 17,
#   'pos': 'midfielder',
#   'rating': '8.40',
#   'realtimegame': 985,
#   'realtimeidle': 5,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 23,
#   'tacklesmade': 8,
#   'vproattr': '090|094|093|087|073|083|086|088|080|083|076|088|078|088|084|088|076|080|066|076|082|079|075|075|080|067|074|078|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 2000612994,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 19,
#   'passesmade': 15,
#   'pos': 'forward',
#   'rating': '8.10',
#   'realtimegame': 985,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 4,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|072|060|056|080|083|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cKlwa'},
#  {'matchId': 24824602830453,
#   'teamId': 16046,
#   'playerId': 1003966668622,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 45,
#   'passesmade': 38,
#   'pos': '',
#   'rating': '6.80',
#   'realtimegame': 986,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 9,
#   'tacklesmade': 2,
#   'vproattr': '098|095|099|095|070|085|059|093|062|085|064|092|076|097|079|099|089|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cFLcaw'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1807883824,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 10,
#   'pos': 'forward',
#   'rating': '7.40',
#   'realtimegame': 985,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 7,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|081|052|082|073|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'AKIJ-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 4,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.90',
#   'realtimegame': 986,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '082|084|063|064|081|090|095|090|099|087|095|062|072|071|071|061|070|062|092|067|075|099|069|069|092|095|060|064|065|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1005046092178,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 11,
#   'pos': 'defender',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 30,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '095|093|089|074|074|091|067|096|072|081|092|082|076|087|084|090|065|072|067|071|087|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'KH2vz'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1006200723046,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 12,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 985,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 14,
#   'tacklesmade': 2,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'cMesi-'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007522546545,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 23,
#   'passesmade': 14,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 986,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|089|089|097|090|095|076|078|059|082|096|052|067|067|060|056|074|092|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'X20X'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007729381653,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 21,
#   'passesmade': 16,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 986,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 0,
#   'tackleattempts': 15,
#   'tacklesmade': 5,
#   'vproattr': '095|093|089|086|074|091|067|096|072|081|095|083|076|090|082|086|065|072|067|071|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'O-D'},
#  {'matchId': 24824602830453,
#   'teamId': 3084976,
#   'playerId': 1007765949717,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 3,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 38,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '6.40',
#   'realtimegame': 986,
#   'realtimeidle': 2,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 3,
#   'shots': 2,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|086|078|059|067|081|052|072|072|060|056|080|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'yKaneL'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25200092700465,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1736817133,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '5.80',
#   'realtimegame': 30,
#   'realtimeidle': 3,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': 'NH',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'xMGdd-'},
#  {'matchId': 25200092700465,
#   'teamId': 2018971,
#   'playerId': 1004370337600,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '4.70',
#   'realtimegame': 31,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 0,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '054|068|032|056|065|048|060|085|040|060|020|020|045|020|025|015|020|020|015|040|040|020|061|015|020|020|015|030|035|090|097|097|096|099|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'M9H3I'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1967783386,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.60',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '080|076|096|094|069|070|058|085|062|083|064|091|093|099|093|097|088|079|063|091|096|065|067|082|067|065|079|098|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'z_Tlo-'},
#  {'matchId': 25196195260448,
#   'teamId': 13791,
#   'playerId': 1999768785,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 1,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'goalkeeper',
#   'rating': '6.10',
#   'realtimegame': 23,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|076|097|079|099|089|084|059|067|083|052|082|072|060|056|080|083|081|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'bn_xi'},
#  {'matchId': 25196195260448,
#   'teamId': 2018971,
# ...
#   'goals': 0,
#   'goalsconceded': 3,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 3,
#   'passesmade': 3,
#   'pos': 'midfielder',
#   'rating': '5.80',
#   'realtimegame': 23230,
#   'realtimeidle': 49,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24932193940123,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.70',
#   'realtimegame': 275,
#   'realtimeidle': 10,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 8,
#   'passesmade': 7,
#   'pos': 'midfielder',
#   'rating': '7.50',
#   'realtimegame': 938,
#   'realtimeidle': 55,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 4,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 5,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 19,
#   'pos': 'midfielder',
#   'rating': '10.00',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 12,
#   'passesmade': 11,
#   'pos': 'midfielder',
#   'rating': '7.40',
#   'realtimegame': 938,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 12,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 916,
#   'realtimeidle': 176,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 938,
#   'realtimeidle': 25,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 1,
#   'tackleattempts': 24,
#   'tacklesmade': 5,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24906309550476,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 2,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 39,
#   'passesmade': 34,
#   'pos': '',
#   'rating': '7.00',
#   'realtimegame': 938,
#   'realtimeidle': 23,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 5,
#   'shots': 6,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '5.30',
#   'realtimegame': 76378,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '7.80',
#   'realtimegame': 855,
#   'realtimeidle': 51,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'midfielder',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007324980209,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': 'forward',
#   'rating': '6.00',
#   'realtimegame': 22765,
#   'realtimeidle': 34,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '087|084|090|086|069|078|058|085|062|083|064|091|090|093|093|091|080|079|069|085|090|065|072|078|067|065|073|094|077|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'abo5ly-_-'},
#  {'matchId': 24906309550476,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 5,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 11,
#   'passesmade': 9,
#   'pos': 'forward',
#   'rating': '5.90',
#   'realtimegame': 938,
#   'realtimeidle': 19,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 1,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '093|091|081|083|072|078|075|085|068|088|060|096|074|088|071|082|095|078|086|068|079|052|083|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1854026811,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 5,
#   'passesmade': 4,
#   'pos': 'midfielder',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 42,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '088|089|072|073|072|093|084|092|091|081|093|072|079|077|085|071|068|072|082|063|075|095|068|071|090|091|067|075|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'iLoRs1-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1960634256,
#   'assists': 2,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 1,
#   'namespace': 1,
#   'passattempts': 25,
#   'passesmade': 22,
#   'pos': 'midfielder',
#   'rating': '9.00',
#   'realtimegame': 962,
#   'realtimeidle': 12,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 2,
#   'tacklesmade': 1,
#   'vproattr': '098|095|099|095|067|077|059|085|062|085|064|092|087|094|090|099|076|080|059|082|091|052|067|067|060|056|074|096|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'lI-OsK'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1969882377,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 22,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.60',
#   'realtimegame': 962,
#   'realtimeidle': 14,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 2,
#   'tackleattempts': 13,
#   'tacklesmade': 1,
#   'vproattr': '091|094|094|088|072|082|085|088|079|083|076|088|077|089|083|091|075|080|065|073|080|078|074|074|079|066|074|079|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'AQ_DAG'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1975587038,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 13,
#   'pos': 'forward',
#   'rating': '8.00',
#   'realtimegame': 2552,
#   'realtimeidle': 101,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 3,
#   'tackleattempts': 1,
#   'tacklesmade': 0,
#   'vproattr': '098|095|099|095|067|079|059|085|062|085|064|092|076|097|079|099|089|082|059|067|081|052|076|074|060|056|080|083|080|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'k-general7'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1006200723046,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 17,
#   'passesmade': 15,
#   'pos': 'midfielder',
#   'rating': '8.00',
#   'realtimegame': 962,
#   'realtimeidle': 13,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 0,
#   'tackleattempts': 19,
#   'tacklesmade': 7,
#   'vproattr': '095|093|086|079|076|096|067|092|072|081|095|079|076|087|082|090|065|072|067|069|081|092|062|065|087|088|064|078|070|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'cMesi-'},
#  {'matchId': 24932154470015,
#   'teamId': 662486,
#   'playerId': 1007590505294,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 3,
#   'goalsconceded': 1,
#   'losses': 0,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 34,
#   'passesmade': 33,
#   'pos': '',
#   'rating': '7.10',
#   'realtimegame': 2242,
#   'realtimeidle': 9,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 4,
#   'shots': 10,
#   'tackleattempts': 23,
#   'tacklesmade': 5,
#   'vproattr': '098|095|099|093|070|085|065|099|065|085|064|089|076|097|079|097|084|078|059|067|081|052|072|067|060|056|074|083|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 1,
#   'playername': 'ByAzi_'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 193083681,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 1,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 76,
#   'passesmade': 70,
#   'pos': '',
#   'rating': '6.00',
#   'realtimegame': 962,
#   'realtimeidle': 29,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 3,
#   'tackleattempts': 40,
#   'tacklesmade': 1,
#   'vproattr': '094|091|082|094|071|076|074|085|066|088|060|099|073|095|071|089|095|082|079|065|081|050|086|092|059|052|088|078|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'ronaldo990'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1873723519,
#   'assists': 1,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 15,
#   'passesmade': 10,
#   'pos': 'midfielder',
#   'rating': '7.90',
#   'realtimegame': 962,
#   'realtimeidle': 6,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 7,
#   'tacklesmade': 4,
#   'vproattr': '098|095|099|087|067|077|059|085|062|085|064|092|087|091|090|099|081|078|059|076|085|052|076|067|060|056|074|090|075|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'co_1j_2'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1003778529393,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'OhhRuthless--'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1005482916657,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 0,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 0,
#   'passesmade': 0,
#   'pos': '',
#   'rating': '3.00',
#   'realtimegame': 0,
#   'realtimeidle': 0,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '',
#   'vprohackreason': 0,
#   'wins': 0,
#   'playername': 'mujahid_m99'},
#  {'matchId': 24932154470015,
#   'teamId': 4152706,
#   'playerId': 1007976149039,
#   'assists': 0,
#   'cleansheetsany': 0,
#   'cleansheetsdef': 0,
#   'cleansheetsgk': 0,
#   'goals': 0,
#   'goalsconceded': 4,
#   'losses': 1,
#   'mom': 0,
#   'namespace': 1,
#   'passattempts': 14,
#   'passesmade': 11,
#   'pos': 'forward',
#   'rating': '6.20',
#   'realtimegame': 962,
#   'realtimeidle': 35,
#   'redcards': 0,
#   'saves': 0,
#   'SCORE': 1,
#   'shots': 0,
#   'tackleattempts': 0,
#   'tacklesmade': 0,
#   'vproattr': '093|091|072|080|075|086|081|099|071|088|060|085|074|081|071|080|095|078|086|068|081|052|087|092|057|050|095|077|083|010|010|010|010|010|',
#   'vprohackreason': 8,
#   'wins': 0,
#   'playername': 'y_a8xx'}]

# %%
duckz = extract_cosmetic_data(json_dict)

# %%
duckz
# Out:
# [{'clubId': 662486,
#   'timestamp': datetime.datetime(2023, 11, 23, 6, 5, 26),
#   'name': 'S  P  U  R  S',
#   'regionId': 5064001,
#   'teamId': 65,
#   'stadName': 'Estadio San Mamés',
#   'kitId': 532483,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160625},
#  {'clubId': 2900086,
#   'timestamp': datetime.datetime(2023, 11, 23, 6, 5, 26),
#   'name': 'Tyaar',
#   'regionId': 5064001,
#   'teamId': 241,
#   'stadName': 'Estadio José Zorrilla',
#   'kitId': 1974272,
#   'seasonalTeamId': 0,
#   'seasonalKitId': 0,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160626},
#  {'clubId': 764421,
#   'timestamp': datetime.datetime(2023, 11, 23, 5, 44, 55),
#   'name': '5Ieha 3I allh',
#   'regionId': 5064001,
#   'teamId': 243,
#   'stadName': 'El Alcoraz',
#   'kitId': 1990656,
#   'seasonalTeamId': 131397,
#   'seasonalKitId': 1076404224,
#   'selectedKitType': 0,
#   'customKitId': 7509,
#   'customAwayKitId': 7509,
#   'customThirdKitId': 7511,
#   'customKeeperKitId': 5005,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160115},
#  {'clubId': 4152706,
#   'timestamp': datetime.datetime(2023, 11, 23, 5, 34, 11),
#   'name': 'Gharafa FC',
#   'regionId': 5064001,
#   'teamId': 112139,
#   'stadName': 'Tier 1 Stadium',
#   'kitId': 918642688,
#   'customKitId': 7509,
#   'kitColor1': 15921906,
#   'kitColor2': 592397,
#   'kitColor3': 592397,
#   'kitColor4': 592397,
#   'customAwayKitId': 7509,
#   'kitAColor1': 592397,
#   'kitAColor2': 15921906,
#   'kitAColor3': 15921906,
#   'kitAColor4': 15921906,
#   'customThirdKitId': 7511,
#   'kitThrdColor1': 12706617,
#   'kitThrdColor2': 33627,
#   'kitThrdColor3': 396864,
#   'kitThrdColor4': 2164288,
#   'customKeeperKitId': 5005,
#   'dCustomKit': 0,
#   'crestColor': -1,
#   'crestAssetId': 99160327,
#   'seasonalTeamId': 0,
#   'seasonalKitId': 0,
#   'selectedKitType': 0}]

# %%
player_data_collect_df = pd.DataFrame(player_stat_list)

# %%
player_data_collect_df
# Out:
#             matchId   teamId       playerId  assists  cleansheetsany  \
# 0    25182250910116    26401      897712440        0               0
# 1    25182250910116    26401     1816663702        0               0
# 2    25182250910116    26401     1916753895        0               0
# 3    25182250910116    26401     1969806916        0               0
# 4    25182250910116    26401  1004757345736        0               0
# ..              ...      ...            ...      ...             ...
# 534  24932154470015  4152706      193083681        0               0
# 535  24932154470015  4152706     1873723519        1               0
# 536  24932154470015  4152706  1003778529393        0               0
# 537  24932154470015  4152706  1005482916657        0               0
# 538  24932154470015  4152706  1007976149039        0               0
#
#      cleansheetsdef  cleansheetsgk  goals  goalsconceded  losses  ...  \
# 0                 0              0      0              2       1  ...
# 1                 0              0      0              2       1  ...
# 2                 0              0      0              2       1  ...
# 3                 0              0      0              2       1  ...
# 4                 0              0      0              2       1  ...
# ..              ...            ...    ...            ...     ...  ...
# 534               0              0      1              4       1  ...
# 535               0              0      0              4       1  ...
# 536               0              0      0              0       1  ...
# 537               0              0      0              0       1  ...
# 538               0              0      0              4       1  ...
#
#      redcards  saves  SCORE  shots tackleattempts tacklesmade  \
# 0           0      0      0      7             10           0
# 1           0      0      0      3              8           3
# 2           0      0      0      0             15           2
# 3           0      0      0      0             11           3
# 4           0      0      0      0              3           0
# ..        ...    ...    ...    ...            ...         ...
# 534         0      0      1      3             40           1
# 535         0      0      1      0              7           4
# 536         0      0      1      0              0           0
# 537         0      0      1      0              0           0
# 538         0      0      1      0              0           0
#
#                                               vproattr  vprohackreason  wins  \
# 0    078|092|080|091|074|087|088|091|072|089|060|09...               8     0
# 1    098|095|099|095|070|085|060|093|062|085|064|09...               8     0
# 2    094|091|090|089|070|083|065|088|071|081|095|08...               8     0
# 3    094|094|095|095|071|081|073|085|071|083|079|09...               8     0
# 4    094|094|075|078|077|087|077|092|086|081|095|07...               8     0
# ..                                                 ...             ...   ...
# 534  094|091|082|094|071|076|074|085|066|088|060|09...               8     0
# 535  098|095|099|087|067|077|059|085|062|085|064|09...               8     0
# 536                                                                  0     0
# 537                                                                  0     0
# 538  093|091|072|080|075|086|081|099|071|088|060|08...               8     0
#
#         playername
# 0            F9lrc
# 1            R-7hp
# 2             lCqk
# 3          DKToR_i
# 4           SZXO_7
# ..             ...
# 534     ronaldo990
# 535        co_1j_2
# 536  OhhRuthless--
# 537    mujahid_m99
# 538         y_a8xx
#
# [539 rows x 28 columns]

# %%
player_data_collect_df = player_data_collect_df[['matchId', 'teamId','playerId','vproattr']]

# %%
player_data_collect_df
# Out:
#             matchId   teamId       playerId  \
# 0    25182250910116    26401      897712440
# 1    25182250910116    26401     1816663702
# 2    25182250910116    26401     1916753895
# 3    25182250910116    26401     1969806916
# 4    25182250910116    26401  1004757345736
# ..              ...      ...            ...
# 534  24932154470015  4152706      193083681
# 535  24932154470015  4152706     1873723519
# 536  24932154470015  4152706  1003778529393
# 537  24932154470015  4152706  1005482916657
# 538  24932154470015  4152706  1007976149039
#
#                                               vproattr
# 0    078|092|080|091|074|087|088|091|072|089|060|09...
# 1    098|095|099|095|070|085|060|093|062|085|064|09...
# 2    094|091|090|089|070|083|065|088|071|081|095|08...
# 3    094|094|095|095|071|081|073|085|071|083|079|09...
# 4    094|094|075|078|077|087|077|092|086|081|095|07...
# ..                                                 ...
# 534  094|091|082|094|071|076|074|085|066|088|060|09...
# 535  098|095|099|087|067|077|059|085|062|085|064|09...
# 536
# 537
# 538  093|091|072|080|075|086|081|099|071|088|060|08...
#
# [539 rows x 4 columns]

# %%
vproattr_key_names = [
    "vproattr_1", "vproattr_2", "vproattr_3", "vproattr_4", "vproattr_5",
    "vproattr_6", "vproattr_7", "vproattr_8", "vproattr_9", "vproattr_10",
    "vproattr_11", "vproattr_12", "vproattr_13", "vproattr_14", "vproattr_15",
    "vproattr_16", "vproattr_17", "vproattr_18", "vproattr_19", "vproattr_20",
    "vproattr_21", "vproattr_22", "vproattr_23", "vproattr_24", "vproattr_25",
    "vproattr_26", "vproattr_27", "vproattr_28", "vproattr_29", "vproattr_30",
    "vproattr_31", "vproattr_32", "vproattr_33", "vproattr_34"
]

# %%
vproattr_key_names = [
    "vproattr_1", "vproattr_2", "vproattr_3", "vproattr_4", "vproattr_5",
    "vproattr_6", "vproattr_7", "vproattr_8", "vproattr_9", "vproattr_10",
    "vproattr_11", "vproattr_12", "vproattr_13", "vproattr_14", "vproattr_15",
    "vproattr_16", "vproattr_17", "vproattr_18", "vproattr_19", "vproattr_20",
    "vproattr_21", "vproattr_22", "vproattr_23", "vproattr_24", "vproattr_25",
    "vproattr_26", "vproattr_27", "vproattr_28", "vproattr_29", "vproattr_30",
    "vproattr_31", "vproattr_32", "vproattr_33", "vproattr_34", "vproattr_35"
]

# Split the values in the 'vproattr' column and create new columns
player_data_collect_df[vproattr_key_names] = player_data_collect_df['vproattr'].str.split('|', expand=True)

# Drop the original 'vproattr' column if needed
player_data_collect_df.drop('vproattr', axis=1, inplace=True)

# Display the resulting DataFrame

player_data_collect_df = pd.DataFrame(player_data_collect_df)
# Out:
# C:\Users\cjrad\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
player_data_collect_df
# Out:
#             matchId   teamId       playerId vproattr_1 vproattr_2 vproattr_3  \
# 0    25182250910116    26401      897712440        078        092        080
# 1    25182250910116    26401     1816663702        098        095        099
# 2    25182250910116    26401     1916753895        094        091        090
# 3    25182250910116    26401     1969806916        094        094        095
# 4    25182250910116    26401  1004757345736        094        094        075
# ..              ...      ...            ...        ...        ...        ...
# 534  24932154470015  4152706      193083681        094        091        082
# 535  24932154470015  4152706     1873723519        098        095        099
# 536  24932154470015  4152706  1003778529393                  None       None
# 537  24932154470015  4152706  1005482916657                  None       None
# 538  24932154470015  4152706  1007976149039        093        091        072
#
#     vproattr_4 vproattr_5 vproattr_6 vproattr_7  ... vproattr_26 vproattr_27  \
# 0          091        074        087        088  ...         047         091
# 1          095        070        085        060  ...         056         080
# 2          089        070        083        065  ...         091         064
# 3          095        071        081        073  ...         075         073
# 4          078        077        087        077  ...         093         065
# ..         ...        ...        ...        ...  ...         ...         ...
# 534        094        071        076        074  ...         052         088
# 535        087        067        077        059  ...         056         074
# 536       None       None       None       None  ...        None        None
# 537       None       None       None       None  ...        None        None
# 538        080        075        086        081  ...         050         095
#
#     vproattr_28 vproattr_29 vproattr_30 vproattr_31 vproattr_32 vproattr_33  \
# 0           076         084         010         010         010         010
# 1           083         075         010         010         010         010
# 2           078         070         010         010         010         010
# 3           079         075         010         010         010         010
# 4           077         072         010         010         010         010
# ..          ...         ...         ...         ...         ...         ...
# 534         078         083         010         010         010         010
# 535         090         075         010         010         010         010
# 536        None        None        None        None        None        None
# 537        None        None        None        None        None        None
# 538         077         083         010         010         010         010
#
#     vproattr_34 vproattr_35
# 0           010
# 1           010
# 2           010
# 3           010
# 4           010
# ..          ...         ...
# 534         010
# 535         010
# 536        None        None
# 537        None        None
# 538         010
#
# [539 rows x 38 columns]
